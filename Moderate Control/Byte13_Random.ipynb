# %%
from sage.all import *
from sage.crypto.boolean_function import BooleanFunction
from random import randint
import random
import numpy

#R.<k0, k1, k2, k3, k4, k5, k6, k7, k8, k9, k10, k11, k12, k13, k14, k15, k16, k17, k18, k19, k20, k21, k22, k23, k24, k25, k26, k27, k28, k29, k30, k31, k32, k33, k34, k35, k36, k37, k38, k39, k40, k41, k42, k43, k44, k45, k46, k47, k48, k49, k50, k51, k52, k53, k54, k55, k56, k57, k58, k59, k60, k61, k62, k63, k64, k65, k66, k67, k68, k69, k70, k71, k72, k73, k74, k75, k76, k77, k78, k79, k80, k81, k82, k83, k84, k85, k86, k87, k88, k89, k90, k91, k92, k93, k94, k95, k96, k97, k98, k99, k100, k101, k102, k103, k104, k105, k106, k107, k108, k109, k110, k111, k112, k113, k114, k115, k116, k117, k118, k119, k120, k121, k122, k123, k124, k125, k126, k127, v0, v1, v2, v3, v4, v5, v6, v7, v8, v9, v10, v11, v12, v13, v14, v15, v16, v17, v18, v19, v20, v21, v22, v23, v24, v25, v26, v27, v28, v29, v30, v31, v32, v33, v34, v35, v36, v37, v38, v39, v40, v41, v42, v43, v44, v45, v46, v47, v48, v49, v50, v51, v52, v53, v54, v55, v56, v57, v58, v59, v60, v61, v62, v63, v64, v65, v66, v67, v68, v69, v70, v71, v72, v73, v74, v75, v76, v77, v78, v79, v80, v81, v82, v83, v84, v85, v86, v87, v88, v89, v90, v91, v92, v93, v94, v95> = BooleanPolynomialRing()
R = BooleanPolynomialRing(names=('s0', 's1', 's2', 's3', 's4', 's5', 's6', 's7', 
                                 's8', 's9', 's10', 's11', 's12', 's13', 's14', 's15', 
                                 's16', 's17', 's18', 's19', 's20', 's21', 's22', 's23', 
                                 's24', 's25', 's26', 's27', 's28', 's29', 's30', 's31', 
                                 's32', 's33', 's34', 's35', 's36', 's37', 's38', 's39', 
                                 's40', 's41', 's42', 's43', 's44', 's45', 's46', 's47', 
                                 's48', 's49', 's50', 's51', 's52', 's53', 's54', 's55', 
                                 's56', 's57', 's58', 's59', 's60', 's61', 's62', 's63', 
                                 's64', 's65', 's66', 's67', 's68', 's69', 's70', 's71', 
                                 's72', 's73', 's74', 's75', 's76', 's77', 's78', 's79', 
                                 's80', 's81', 's82', 's83', 's84', 's85', 's86', 's87', 
                                 's88', 's89', 's90', 's91', 's92', 's93', 's94', 's95', 
                                 's96', 's97', 's98', 's99', 's100', 's101', 's102', 's103', 
                                 's104', 's105', 's106', 's107', 's108', 's109', 's110', 's111', 
                                 's112', 's113', 's114', 's115', 's116', 's117', 's118', 's119', 
                                 's120', 's121', 's122', 's123', 's124', 's125', 's126', 's127', 
                                 'k0', 'k1', 'k2', 'k3', 'k4', 'k5', 'k6', 'k7', 
                                 'k8', 'k9', 'k10', 'k11', 'k12', 'k13', 'k14', 'k15', 
                                 'k16', 'k17', 'k18', 'k19', 'k20', 'k21', 'k22', 'k23', 
                                 'k24', 'k25', 'k26', 'k27', 'k28', 'k29', 'k30', 'k31', 
                                 'k32', 'k33', 'k34', 'k35', 'k36', 'k37', 'k38', 'k39', 
                                 'k40', 'k41', 'k42', 'k43', 'k44', 'k45', 'k46', 'k47', 
                                 'k48', 'k49', 'k50', 'k51', 'k52', 'k53', 'k54', 'k55', 
                                 'k56', 'k57', 'k58', 'k59', 'k60', 'k61', 'k62', 'k63', 
                                 'k64', 'k65', 'k66', 'k67', 'k68', 'k69', 'k70', 'k71', 
                                 'k72', 'k73', 'k74', 'k75', 'k76', 'k77', 'k78', 'k79', 
                                 'k80', 'k81', 'k82', 'k83', 'k84', 'k85', 'k86', 'k87', 
                                 'k88', 'k89', 'k90', 'k91', 'k92', 'k93', 'k94', 'k95', 
                                 'k96', 'k97', 'k98', 'k99', 'k100', 'k101', 'k102', 'k103', 
                                 'k104', 'k105', 'k106', 'k107', 'k108', 'k109', 'k110', 'k111', 
                                 'k112', 'k113', 'k114', 'k115', 'k116', 'k117', 'k118', 'k119', 
                                 'k120', 'k121', 'k122', 'k123', 'k124', 'k125', 'k126', 'k127'))
R.inject_variables()
S = [0 for u in range(128)]
nonce = [R(random.randint(0,1)) for u in range(96)]
message = [0 for u in range(32)]
wrongTraversed = [0 for u in range (8)]
rightTraversed = [0 for u in range (8)]
fault = 0
correct = 0
false = 0

FrameBitsIV = [1,0,0]
FrameBitsAD = [1,1,0]
FrameBitsPC = [1,0,1]

#State Update
def state_Update (S,K,i) :
    for j in range(i):#try to increase 32 bits at a time
        feedback = S[0] + S[47] + S[70]*S[85] + S[91] + 1 + K[j%128]
        
        for k in range(127):
            S[k] = S[k+1]
        S[127] = feedback
        
def state_Update2 (S,K,i) :
    for j in range(i):#try to increase 32 bits at a time
        feedback = S[0] + S[47] + S[70]*S[85] + S[91] + 1 + K[(j+96)%128]
        
        for k in range(127):
            S[k] = S[k+1]
        S[127] = feedback
        
#initialization
def initialization (S, K, nonce) :
    S = [0 for u in range(128)]
    
    state_Update(S, K, 1024)  
    
    for i in range(0,3) :
        
        for j in range (0,3) :
            S[36+j] = S[36+j] + FrameBitsIV[j]
            
        state_Update(S,K,640)
        
        for j in range (0,32):
            temp = (32 * i) + j
            S[96+j] = S[96+j] + nonce[temp]
            
#encryption           
def encrypt (S, K, m, mlen) :
    
    for i in range (0, floor(mlen/32)):
        for j in range (0,3) :
            S[36+j] = S[36+j] + FrameBitsPC[j]
            
        state_Update(S,K,864) #1024 - 160 rounds
        
       #for j in range (0,32):
            #temp = (32 * i) + j
            #S[96+j] = S[96+j] + m[temp]
            #c[temp] = S [64 + j] + m[temp]
print('\n')
print("The very first initial state :",S)
print('\n')
z=0
while (z <= 10):
    y = 0
    S1 = list(R.gens()[0:128])
    S2 = list(R.gens()[104:112])
    S_128 = list(R.gens()[0:128])
    print(S2)
    traversed = []
    K = [R(random.randint(0,1)) for u in range(128)]
    K1 = list(R.gens()[128:256])
    initialization(S,K,nonce)
    encrypt(S,K,message,len(message))
    
    initial_State = list(S) #Storing Initial State Values
    print('\n')
    
    state_Update2(S,K,160)
    state_Update2(S1,K1,160)
    
    while len(traversed) < 8 and y < 1 :
        check = [0 for u in range (96)]
        errorLocation = random.randrange(104,112)
        e = random.randint(0,1)
        faulty = list(initial_State)
        faulty[errorLocation] = faulty[errorLocation] + e
        print("Fault injected at S[",errorLocation,"] (not known to adversary)")
        print('\n')
        fault = fault+1

        state_Update2(faulty,K,160)
        
        for k in range(64,96,1):
            if faulty[k] + S[k] == 1:
                check[k] = check[k] + 1
                print("Affected Keystream index [",k,"] =",check[k])
        print('\n')
        
        if (faulty[72] + S[72] == 1 and faulty[92] + S[92] == 1 and faulty[76] + S[76] != 1):
            print(S2[0],"has been flipped")
            if (errorLocation == 104):
                print("Correct guess!")
                if errorLocation not in traversed:
                    traversed.append(errorLocation)
                    correct = correct + 1
                    rightTraversed[0] = rightTraversed[0] + 1
                else:
                    print("This bit has been checked. re-inject fault")
            else :
                if  errorLocation not in traversed:
                    traversed.append(errorLocation)
                    false = false + 1
                    wrongTraversed[errorLocation-104] = wrongTraversed[errorLocation-104] + 1
                print("The right error location:",errorLocation)
                print("Equation 1 :", diff(S1[72],S_128[errorLocation]))
                print("Equation 2 :", diff(S1[92],S_128[errorLocation]))
            print('-------------------------------------------------------------------------')
            print('\n')
                
        elif (faulty[73] + S[73] == 1 and faulty[93] + S[93] == 1 and faulty[77] + S[77] != 1 ):
            print(S2[1],"has been flipped")
            if (errorLocation == 105):
                print("Correct guess!")
                if errorLocation not in traversed:
                    traversed.append(errorLocation)
                    correct = correct + 1
                    rightTraversed[1] = rightTraversed[1] + 1
                else:
                    print("This bit has been checked. re-inject fault")
            else :
                if  errorLocation not in traversed:
                    traversed.append(errorLocation)
                    false = false + 1
                    wrongTraversed[errorLocation-104] = wrongTraversed[errorLocation-104] + 1
                print("The right error location:",errorLocation)
                print("Equation 1 :", diff(S1[73],S_128[errorLocation]))
                print("Equation 2 :", diff(S1[93],S_128[errorLocation]))
            print('-------------------------------------------------------------------------')
            print('\n')
                
        elif (faulty[74] + S[74] == 1 and faulty[94] + S[94] == 1 and faulty[78] + S[78] != 1 ):
            print(S2[2],"has been flipped")
            if (errorLocation == 106):
                print("Correct guess!")
                if errorLocation not in traversed:
                    traversed.append(errorLocation)
                    correct = correct + 1
                    rightTraversed[2] = rightTraversed[2] + 1
                else:
                    print("This bit has been checked. re-inject fault")
            else :
                if  errorLocation not in traversed:
                    traversed.append(errorLocation)
                    false = false + 1
                    wrongTraversed[errorLocation-104] = wrongTraversed[errorLocation-104] + 1
                print("The right error location:",errorLocation)
                print("Equation 1 :", diff(S1[74],S_128[errorLocation]))
                print("Equation 2 :", diff(S1[94],S_128[errorLocation]))
            print('-------------------------------------------------------------------------')
            print('\n')
                      
        elif (faulty[75] + S[75] == 1 and faulty[95] + S[95] == 1 and faulty[79] + S[79] != 1):
            print(S2[3],"has been flipped")
            if (errorLocation == 107):
                print("Correct guess!")
                if errorLocation not in traversed:
                    traversed.append(errorLocation)
                    correct = correct + 1
                    rightTraversed[3] = rightTraversed[3] + 1
                else:
                    print("This bit has been checked. re-inject fault")
            else :
                if  errorLocation not in traversed:
                    traversed.append(errorLocation)
                    false = false + 1
                    wrongTraversed[errorLocation-104] = wrongTraversed[errorLocation-104] + 1
                print("The right error location:",errorLocation)
                print("Equation 1 :", diff(S1[75],S_128[errorLocation]))
                print("Equation 2 :", diff(S1[95],S_128[errorLocation]))
            print('-------------------------------------------------------------------------')
            print('\n')
                
        elif (faulty[76] + S[76] == 1 and faulty[75] + S[75] != 1 and (faulty[72] + S[72] != 1 or faulty[92] + S[92] != 1)):
            print(S2[4],"has been flipped")
            if (errorLocation == 108):
                print("Correct guess!")
                if errorLocation not in traversed:
                    traversed.append(errorLocation)
                    correct = correct + 1
                    rightTraversed[4] = rightTraversed[4] + 1
                else:
                    print("This bit has been checked. re-inject fault")
            else :
                if  errorLocation not in traversed:
                    traversed.append(errorLocation)
                    false = false + 1
                    wrongTraversed[errorLocation-104] = wrongTraversed[errorLocation-104] + 1
                print("The right error location:",errorLocation)
                print("Equation :", diff(S1[76],S_128[errorLocation]))
            print('-------------------------------------------------------------------------')
            print('\n')
                
        elif (faulty[77] + S[77] == 1 and faulty[76] + S[76] != 1 and (faulty[73] + S[73] != 1 or faulty[93] + S[93] != 1)):
            print(S2[5],"has been flipped")
            if (errorLocation == 109):
                print("Correct guess!")
                if errorLocation not in traversed:
                    traversed.append(errorLocation)
                    correct = correct + 1
                    rightTraversed[5] = rightTraversed[5] + 1
                else:
                    print("This bit has been checked. re-inject fault")
            else :
                if  errorLocation not in traversed:
                    traversed.append(errorLocation)
                    false = false + 1
                    wrongTraversed[errorLocation-104] = wrongTraversed[errorLocation-104] + 1
                print("The right error location:",errorLocation)
                print("Equation :", diff(S1[77],S_128[errorLocation]))
            print('-------------------------------------------------------------------------')
            print('\n')
                
        elif (faulty[78] + S[78] == 1 and faulty[77] + S[77] != 1 and (faulty[74] + S[74] != 1 or faulty[94] + S[94] != 1)):
            print(S2[6],"has been flipped")
            if (errorLocation == 110):
                print("Correct guess!")
                if errorLocation not in traversed:
                    traversed.append(errorLocation)
                    correct = correct + 1
                    rightTraversed[6] = rightTraversed[6] + 1
                else:
                    print("This bit has been checked. re-inject fault")
            else :
                if  errorLocation not in traversed:
                    traversed.append(errorLocation)
                    false = false + 1
                    wrongTraversed[errorLocation-104] = wrongTraversed[errorLocation-104] + 1
                print("The right error location:",errorLocation)
                print("Equation :", diff(S1[78],S_128[errorLocation]))
            print('-------------------------------------------------------------------------')
            print('\n')
                
        elif (faulty[79] + S[79] == 1 and faulty[78] + S[78] != 1 and (faulty[75] + S[75] != 1 or faulty[95] + S[95] != 1)):
            print(S2[7],"has been flipped")
            if (errorLocation == 111):
                print("Correct guess!")
                if errorLocation not in traversed:
                    traversed.append(errorLocation)
                    correct = correct + 1
                    rightTraversed[7] = rightTraversed[7] + 1
                else:
                    print("This bit has been checked. re-inject fault")
            else :
                if  errorLocation not in traversed:
                    traversed.append(errorLocation)
                    false = false + 1
                    wrongTraversed[errorLocation-104] = wrongTraversed[errorLocation-104] + 1
                print("The right error location:",errorLocation)
                print("Equation :", diff(S1[79],S_128[errorLocation]))
            print('-------------------------------------------------------------------------')
            print('\n')
            
        elif (e == 1):
            print("The fault location is undeterminable.")
            print("Fault:",e)
            y = y+1
            print('-------------------------------------------------------------------------')
            if  errorLocation not in traversed:
                traversed.append(errorLocation)
                false = false + 1
                wrongTraversed[errorLocation-104] = wrongTraversed[errorLocation-104] + 1
            print('\n')
            
        else:
            print("Fault injection failed. Please inject fault again.")
            print("Fault:",e)
            print('-------------------------------------------------------------------------')
            print('\n')
    print("Traversed:",traversed)
    if (y == 0):
        z = z + 1
#         print("Total Faults needed:",fault)
#         print("Total guesses:",false+correct)
#         print("Total right guesses:",correct)
#         print("Total not guessed:",false)
#         print("Number of times where all bits are can be guessed in 1000 rounds:",z)
#         print('\n')
#         print("Undeterminable location (How many times undeterminable)")
#         for i in range (0,8,1):
#             print("S[",i+104,"] =",wrongTraversed[i])
#         print("\n")
#         print("Right guess location (How many times guessed right)")
#         for i in range (0,8,1):
#             print("S[",i+104,"] =",rightTraversed[i])
#         print("\n")
#         print("Right Guess/Total Guess for each target location")
#         for i in range (0,8,1):
#             print("S[",i+104,"] =",rightTraversed[i]/(rightTraversed[i]+wrongTraversed[i]))
        
        

print("Total Faults needed:",fault)
print("Total guesses:",false+correct)
print("Total right guesses:",correct)
print("Total not guessed:",false)
print("Number of times where all bits are can be guessed in 1000 rounds:",z)
print('\n')
print("Undeterminable location (How many times undeterminable)")
for i in range (0,8,1):
    print("S[",i+104,"] =",wrongTraversed[i])
print("\n")
print("Right guess location (How many times guessed right)")
for i in range (0,8,1):
    print("S[",i+104,"] =",rightTraversed[i])
print("\n")
print("Right Guess/Total Guess for each target location")
for i in range (0,8,1):
    print("S[",i+104,"] =",rightTraversed[i]/(rightTraversed[i]+wrongTraversed[i]))
# Out:
# Defining s0, s1, s2, s3, s4, s5, s6, s7, s8, s9, s10, s11, s12, s13, s14, s15, s16, s17, s18, s19, s20, s21, s22, s23, s24, s25, s26, s27, s28, s29, s30, s31, s32, s33, s34, s35, s36, s37, s38, s39, s40, s41, s42, s43, s44, s45, s46, s47, s48, s49, s50, s51, s52, s53, s54, s55, s56, s57, s58, s59, s60, s61, s62, s63, s64, s65, s66, s67, s68, s69, s70, s71, s72, s73, s74, s75, s76, s77, s78, s79, s80, s81, s82, s83, s84, s85, s86, s87, s88, s89, s90, s91, s92, s93, s94, s95, s96, s97, s98, s99, s100, s101, s102, s103, s104, s105, s106, s107, s108, s109, s110, s111, s112, s113, s114, s115, s116, s117, s118, s119, s120, s121, s122, s123, s124, s125, s126, s127, k0, k1, k2, k3, k4, k5, k6, k7, k8, k9, k10, k11, k12, k13, k14, k15, k16, k17, k18, k19, k20, k21, k22, k23, k24, k25, k26, k27, k28, k29, k30, k31, k32, k33, k34, k35, k36, k37, k38, k39, k40, k41, k42, k43, k44, k45, k46, k47, k48, k49, k50, k51, k52, k53, k54, k55, k56, k57, k58, k59, k60, k61, k62, k63, k64, k65, k66, k67, k
# ...
