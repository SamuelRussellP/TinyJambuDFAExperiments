# %%
from sage.all import *
from sage.crypto.boolean_function import BooleanFunction
from random import randint
import random
import numpy

#R.<k0, k1, k2, k3, k4, k5, k6, k7, k8, k9, k10, k11, k12, k13, k14, k15, k16, k17, k18, k19, k20, k21, k22, k23, k24, k25, k26, k27, k28, k29, k30, k31, k32, k33, k34, k35, k36, k37, k38, k39, k40, k41, k42, k43, k44, k45, k46, k47, k48, k49, k50, k51, k52, k53, k54, k55, k56, k57, k58, k59, k60, k61, k62, k63, k64, k65, k66, k67, k68, k69, k70, k71, k72, k73, k74, k75, k76, k77, k78, k79, k80, k81, k82, k83, k84, k85, k86, k87, k88, k89, k90, k91, k92, k93, k94, k95, k96, k97, k98, k99, k100, k101, k102, k103, k104, k105, k106, k107, k108, k109, k110, k111, k112, k113, k114, k115, k116, k117, k118, k119, k120, k121, k122, k123, k124, k125, k126, k127, v0, v1, v2, v3, v4, v5, v6, v7, v8, v9, v10, v11, v12, v13, v14, v15, v16, v17, v18, v19, v20, v21, v22, v23, v24, v25, v26, v27, v28, v29, v30, v31, v32, v33, v34, v35, v36, v37, v38, v39, v40, v41, v42, v43, v44, v45, v46, v47, v48, v49, v50, v51, v52, v53, v54, v55, v56, v57, v58, v59, v60, v61, v62, v63, v64, v65, v66, v67, v68, v69, v70, v71, v72, v73, v74, v75, v76, v77, v78, v79, v80, v81, v82, v83, v84, v85, v86, v87, v88, v89, v90, v91, v92, v93, v94, v95> = BooleanPolynomialRing()
R = BooleanPolynomialRing(names=('s0', 's1', 's2', 's3', 's4', 's5', 's6', 's7', 
                                 's8', 's9', 's10', 's11', 's12', 's13', 's14', 's15', 
                                 's16', 's17', 's18', 's19', 's20', 's21', 's22', 's23', 
                                 's24', 's25', 's26', 's27', 's28', 's29', 's30', 's31', 
                                 's32', 's33', 's34', 's35', 's36', 's37', 's38', 's39', 
                                 's40', 's41', 's42', 's43', 's44', 's45', 's46', 's47', 
                                 's48', 's49', 's50', 's51', 's52', 's53', 's54', 's55', 
                                 's56', 's57', 's58', 's59', 's60', 's61', 's62', 's63', 
                                 's64', 's65', 's66', 's67', 's68', 's69', 's70', 's71', 
                                 's72', 's73', 's74', 's75', 's76', 's77', 's78', 's79', 
                                 's80', 's81', 's82', 's83', 's84', 's85', 's86', 's87', 
                                 's88', 's89', 's90', 's91', 's92', 's93', 's94', 's95', 
                                 's96', 's97', 's98', 's99', 's100', 's101', 's102', 's103', 
                                 's104', 's105', 's106', 's107', 's108', 's109', 's110', 's111', 
                                 's112', 's113', 's114', 's115', 's116', 's117', 's118', 's119', 
                                 's120', 's121', 's122', 's123', 's124', 's125', 's126', 's127', 
                                 'k0', 'k1', 'k2', 'k3', 'k4', 'k5', 'k6', 'k7', 
                                 'k8', 'k9', 'k10', 'k11', 'k12', 'k13', 'k14', 'k15', 
                                 'k16', 'k17', 'k18', 'k19', 'k20', 'k21', 'k22', 'k23', 
                                 'k24', 'k25', 'k26', 'k27', 'k28', 'k29', 'k30', 'k31', 
                                 'k32', 'k33', 'k34', 'k35', 'k36', 'k37', 'k38', 'k39', 
                                 'k40', 'k41', 'k42', 'k43', 'k44', 'k45', 'k46', 'k47', 
                                 'k48', 'k49', 'k50', 'k51', 'k52', 'k53', 'k54', 'k55', 
                                 'k56', 'k57', 'k58', 'k59', 'k60', 'k61', 'k62', 'k63', 
                                 'k64', 'k65', 'k66', 'k67', 'k68', 'k69', 'k70', 'k71', 
                                 'k72', 'k73', 'k74', 'k75', 'k76', 'k77', 'k78', 'k79', 
                                 'k80', 'k81', 'k82', 'k83', 'k84', 'k85', 'k86', 'k87', 
                                 'k88', 'k89', 'k90', 'k91', 'k92', 'k93', 'k94', 'k95', 
                                 'k96', 'k97', 'k98', 'k99', 'k100', 'k101', 'k102', 'k103', 
                                 'k104', 'k105', 'k106', 'k107', 'k108', 'k109', 'k110', 'k111', 
                                 'k112', 'k113', 'k114', 'k115', 'k116', 'k117', 'k118', 'k119', 
                                 'k120', 'k121', 'k122', 'k123', 'k124', 'k125', 'k126', 'k127'))
R.inject_variables()
S = list(R.gens()[0:128])
S_128 = list(R.gens()[0:128])
K = list(R.gens()[128:256])
C = R.cover_ring()

eqList = ["eq"]

#State Update
for i in range(128):#try to increase 32 bits at a time
    feedback = S[0] + S[47] + S[70]*S[85] + S[91] + 1 + K[i%128]
    for j in range(127):
        S[j] = S[j+1]
    S[127] = feedback
    
print('\n')
for i in range (64,96,1): 
    print("S =", i)
    #print(S[i])
    print('\n')
    for j in range (0,128):
        for k in range (0,128):
            X = R(diff(C(S[i]),C(S_128[j]),C(S_128[k])))
            if X !=0 and X != 1:
                if X.degree() <= 2:
                #poly = str(X)                
                #if poly.find("*")<0:
                    print ('Differentiate with respect to:', S_128[j] ,"and", S_128[k])
                    print("Result After Differentiation:")
                    print (X)
                    print("Degree :" , X.degree())
                    print('\n')  
    print ('--------------------------------------------------------------------------------------------------------------')
# Out:
# Defining s0, s1, s2, s3, s4, s5, s6, s7, s8, s9, s10, s11, s12, s13, s14, s15, s16, s17, s18, s19, s20, s21, s22, s23, s24, s25, s26, s27, s28, s29, s30, s31, s32, s33, s34, s35, s36, s37, s38, s39, s40, s41, s42, s43, s44, s45, s46, s47, s48, s49, s50, s51, s52, s53, s54, s55, s56, s57, s58, s59, s60, s61, s62, s63, s64, s65, s66, s67, s68, s69, s70, s71, s72, s73, s74, s75, s76, s77, s78, s79, s80, s81, s82, s83, s84, s85, s86, s87, s88, s89, s90, s91, s92, s93, s94, s95, s96, s97, s98, s99, s100, s101, s102, s103, s104, s105, s106, s107, s108, s109, s110, s111, s112, s113, s114, s115, s116, s117, s118, s119, s120, s121, s122, s123, s124, s125, s126, s127, k0, k1, k2, k3, k4, k5, k6, k7, k8, k9, k10, k11, k12, k13, k14, k15, k16, k17, k18, k19, k20, k21, k22, k23, k24, k25, k26, k27, k28, k29, k30, k31, k32, k33, k34, k35, k36, k37, k38, k39, k40, k41, k42, k43, k44, k45, k46, k47, k48, k49, k50, k51, k52, k53, k54, k55, k56, k57, k58, k59, k60, k61, k62, k63, k64, k65, k66, k67, k68, k69, k70, k71, k72, k73, k74, k75, k76, k77, k78, k79, k80, k81, k82, k83, k84, k85, k86, k87, k88, k89, k90, k91, k92, k93, k94, k95, k96, k97, k98, k99, k100, k101, k102, k103, k104, k105, k106, k107, k108, k109, k110, k111, k112, k113, k114, k115, k116, k117, k118, k119, k120, k121, k122, k123, k124, k125, k126, k127
#
#
# S = 64
#
#
# Differentiate with respect to: s6 and s91
# Result After Differentiation:
# s106
# Degree : 1
#
#
# Differentiate with respect to: s6 and s106
# Result After Differentiation:
# s91
# Degree : 1
#
#
# Differentiate with respect to: s21 and s76
# Result After Differentiation:
# s91
# Degree : 1
#
#
# Differentiate with respect to: s21 and s91
# Result After Differentiation:
# s76
# Degree : 1
#
#
# Differentiate with respect to: s53 and s91
# Result After Differentiation:
# s106
# Degree : 1
#
#
# Differentiate with respect to: s53 and s106
# Result After Differentiation:
# s91
# Degree : 1
#
#
# Differentiate with respect to: s68 and s76
# Result After Differentiation:
# s91
# Degree : 1
#
#
# Differentiate with respect to: s68 and s91
# Result After Differentiation:
# s76
# Degree : 1
#
#
# Differentiate with respect to: s76 and s21
# Result After Differentiation:
# s91
# Degree : 1
#
#
# Differentiate with respect to: s76 and s68
# Result After Differentiation:
# s91
# Degree : 1
#
#
# Differentiate with respect to: s76 and s91
# Result After Differentiation:
# s21 + s68 + s106 + s112 + k21 + 1
# Degree : 1
#
#
# Differentiate with respect to: s76 and s106
# Result After Differentiation:
# s91
# Degree : 1
#
#
# Differentiate with respect to: s76 and s112
# Result After Differentiation:
# s91
# Degree : 1
#
#
# Differentiate with respect to: s91 and s6
# Result After Differentiation:
# s106
# Degree : 1
#
#
# Differentiate with respect to: s91 and s21
# Result After Differentiation:
# s76
# Degree : 1
#
#
# Differentiate with respect to: s91 and s53
# Result After Differentiation:
# s106
# Degree : 1
#
#
# Differentiate with respect to: s91 and s68
# Result After Differentiation:
# s76
# Degree : 1
#
#
# Differentiate with respect to: s91 and s76
# Result After Differentiation:
# s21 + s68 + s106 + s112 + k21 + 1
# Degree : 1
#
#
# Differentiate with respect to: s91 and s97
# Result After Differentiation:
# s106
# Degree : 1
#
#
# Differentiate with respect to: s91 and s106
# Result After Differentiation:
# s6 + s53 + s76 + s97 + k6 + 1
# Degree : 1
#
#
# Differentiate with respect to: s91 and s112
# Result After Differentiation:
# s76
# Degree : 1
#
#
# Differentiate with respect to: s97 and s91
# Result After Differentiation:
# s106
# Degree : 1
#
#
# Differentiate with respect to: s97 and s106
# Result After Differentiation:
# s91
# Degree : 1
#
#
# Differentiate with respect to: s106 and s6
# Result After Differentiation:
# s91
# Degree : 1
#
#
# Differentiate with respect to: s106 and s53
# Result After Differentiation:
# s91
# Degree : 1
#
#
# Differentiate with respect to: s106 and s76
# Result After Differentiation:
# s91
# Degree : 1
#
#
# Differentiate with respect to: s106 and s91
# Result After Differentiation:
# s6 + s53 + s76 + s97 + k6 + 1
# Degree : 1
#
#
# Differentiate with respect to: s106 and s97
# Result After Differentiation:
# s91
# Degree : 1
#
#
# Differentiate with respect to: s112 and s76
# Result After Differentiation:
# s91
# Degree : 1
#
#
# Differentiate with respect to: s112 and s91
# Result After Differentiation:
# s76
# Degree : 1
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 65
#
#
# Differentiate with respect to: s7 and s92
# Result After Differentiation:
# s107
# Degree : 1
#
#
# Differentiate with respect to: s7 and s107
# Result After Differentiation:
# s92
# Degree : 1
#
#
# Differentiate with respect to: s22 and s77
# Result After Differentiation:
# s92
# Degree : 1
#
#
# Differentiate with respect to: s22 and s92
# Result After Differentiation:
# s77
# Degree : 1
#
#
# Differentiate with respect to: s54 and s92
# Result After Differentiation:
# s107
# Degree : 1
#
#
# Differentiate with respect to: s54 and s107
# Result After Differentiation:
# s92
# Degree : 1
#
#
# Differentiate with respect to: s69 and s77
# Result After Differentiation:
# s92
# Degree : 1
#
#
# Differentiate with respect to: s69 and s92
# Result After Differentiation:
# s77
# Degree : 1
#
#
# Differentiate with respect to: s77 and s22
# Result After Differentiation:
# s92
# Degree : 1
#
#
# Differentiate with respect to: s77 and s69
# Result After Differentiation:
# s92
# Degree : 1
#
#
# Differentiate with respect to: s77 and s92
# Result After Differentiation:
# s22 + s69 + s107 + s113 + k22 + 1
# Degree : 1
#
#
# Differentiate with respect to: s77 and s107
# Result After Differentiation:
# s92
# Degree : 1
#
#
# Differentiate with respect to: s77 and s113
# Result After Differentiation:
# s92
# Degree : 1
#
#
# Differentiate with respect to: s92 and s7
# Result After Differentiation:
# s107
# Degree : 1
#
#
# Differentiate with respect to: s92 and s22
# Result After Differentiation:
# s77
# Degree : 1
#
#
# Differentiate with respect to: s92 and s54
# Result After Differentiation:
# s107
# Degree : 1
#
#
# Differentiate with respect to: s92 and s69
# Result After Differentiation:
# s77
# Degree : 1
#
#
# Differentiate with respect to: s92 and s77
# Result After Differentiation:
# s22 + s69 + s107 + s113 + k22 + 1
# Degree : 1
#
#
# Differentiate with respect to: s92 and s98
# Result After Differentiation:
# s107
# Degree : 1
#
#
# Differentiate with respect to: s92 and s107
# Result After Differentiation:
# s7 + s54 + s77 + s98 + k7 + 1
# Degree : 1
#
#
# Differentiate with respect to: s92 and s113
# Result After Differentiation:
# s77
# Degree : 1
#
#
# Differentiate with respect to: s98 and s92
# Result After Differentiation:
# s107
# Degree : 1
#
#
# Differentiate with respect to: s98 and s107
# Result After Differentiation:
# s92
# Degree : 1
#
#
# Differentiate with respect to: s107 and s7
# Result After Differentiation:
# s92
# Degree : 1
#
#
# Differentiate with respect to: s107 and s54
# Result After Differentiation:
# s92
# Degree : 1
#
#
# Differentiate with respect to: s107 and s77
# Result After Differentiation:
# s92
# Degree : 1
#
#
# Differentiate with respect to: s107 and s92
# Result After Differentiation:
# s7 + s54 + s77 + s98 + k7 + 1
# Degree : 1
#
#
# Differentiate with respect to: s107 and s98
# Result After Differentiation:
# s92
# Degree : 1
#
#
# Differentiate with respect to: s113 and s77
# Result After Differentiation:
# s92
# Degree : 1
#
#
# Differentiate with respect to: s113 and s92
# Result After Differentiation:
# s77
# Degree : 1
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 66
#
#
# Differentiate with respect to: s8 and s93
# Result After Differentiation:
# s108
# Degree : 1
#
#
# Differentiate with respect to: s8 and s108
# Result After Differentiation:
# s93
# Degree : 1
#
#
# Differentiate with respect to: s23 and s78
# Result After Differentiation:
# s93
# Degree : 1
#
#
# Differentiate with respect to: s23 and s93
# Result After Differentiation:
# s78
# Degree : 1
#
#
# Differentiate with respect to: s55 and s93
# Result After Differentiation:
# s108
# Degree : 1
#
#
# Differentiate with respect to: s55 and s108
# Result After Differentiation:
# s93
# Degree : 1
#
#
# Differentiate with respect to: s70 and s78
# Result After Differentiation:
# s93
# Degree : 1
#
#
# Differentiate with respect to: s70 and s93
# Result After Differentiation:
# s78
# Degree : 1
#
#
# Differentiate with respect to: s78 and s23
# Result After Differentiation:
# s93
# Degree : 1
#
#
# Differentiate with respect to: s78 and s70
# Result After Differentiation:
# s93
# Degree : 1
#
#
# Differentiate with respect to: s78 and s93
# Result After Differentiation:
# s23 + s70 + s108 + s114 + k23 + 1
# Degree : 1
#
#
# Differentiate with respect to: s78 and s108
# Result After Differentiation:
# s93
# Degree : 1
#
#
# Differentiate with respect to: s78 and s114
# Result After Differentiation:
# s93
# Degree : 1
# Differentiate with respect to: s93 and s8
# Result After Differentiation:
# s108
# Degree : 1
#
#
# Differentiate with respect to: s93 and s23
# Result After Differentiation:
# s78
# Degree : 1
#
#
# Differentiate with respect to: s93 and s55
# Result After Differentiation:
# s108
# Degree : 1
#
#
# Differentiate with respect to: s93 and s70
# Result After Differentiation:
# s78
# Degree : 1
#
#
# Differentiate with respect to: s93 and s78
# Result After Differentiation:
# s23 + s70 + s108 + s114 + k23 + 1
# Degree : 1
#
#
# Differentiate with respect to: s93 and s99
# Result After Differentiation:
# s108
# Degree : 1
#
#
# Differentiate with respect to: s93 and s108
# Result After Differentiation:
# s8 + s55 + s78 + s99 + k8 + 1
# Degree : 1
#
#
# Differentiate with respect to: s93 and s114
# Result After Differentiation:
# s78
# Degree : 1
#
#
# Differentiate with respect to: s99 and s93
# Result After Differentiation:
# s108
# Degree : 1
#
#
# Differentiate with respect to: s99 and s108
# Result After Differentiation:
# s93
# Degree : 1
#
#
# Differentiate with respect to: s108 and s8
# Result After Differentiation:
# s93
# Degree : 1
#
#
# Differentiate with respect to: s108 and s55
# Result After Differentiation:
# s93
# Degree : 1
#
#
# Differentiate with respect to: s108 and s78
# Result After Differentiation:
# s93
# Degree : 1
#
#
# Differentiate with respect to: s108 and s93
# Result After Differentiation:
# s8 + s55 + s78 + s99 + k8 + 1
# Degree : 1
#
#
# Differentiate with respect to: s108 and s99
# Result After Differentiation:
# s93
# Degree : 1
#
#
# Differentiate with respect to: s114 and s78
# Result After Differentiation:
# s93
# Degree : 1
#
#
# Differentiate with respect to: s114 and s93
# Result After Differentiation:
# s78
# Degree : 1
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 67
#
#
# Differentiate with respect to: s9 and s94
# Result After Differentiation:
# s109
# Degree : 1
#
#
# Differentiate with respect to: s9 and s109
# Result After Differentiation:
# s94
# Degree : 1
#
#
# Differentiate with respect to: s24 and s79
# Result After Differentiation:
# s94
# Degree : 1
#
#
# Differentiate with respect to: s24 and s94
# Result After Differentiation:
# s79
# Degree : 1
#
#
# Differentiate with respect to: s56 and s94
# Result After Differentiation:
# s109
# Degree : 1
#
#
# Differentiate with respect to: s56 and s109
# Result After Differentiation:
# s94
# Degree : 1
#
#
# Differentiate with respect to: s71 and s79
# Result After Differentiation:
# s94
# Degree : 1
#
#
# Differentiate with respect to: s71 and s94
# Result After Differentiation:
# s79
# Degree : 1
#
#
# Differentiate with respect to: s79 and s24
# Result After Differentiation:
# s94
# Degree : 1
#
#
# Differentiate with respect to: s79 and s71
# Result After Differentiation:
# s94
# Degree : 1
#
#
# Differentiate with respect to: s79 and s94
# Result After Differentiation:
# s24 + s71 + s109 + s115 + k24 + 1
# Degree : 1
#
#
# Differentiate with respect to: s79 and s109
# Result After Differentiation:
# s94
# Degree : 1
#
#
# Differentiate with respect to: s79 and s115
# Result After Differentiation:
# s94
# Degree : 1
#
#
# Differentiate with respect to: s94 and s9
# Result After Differentiation:
# s109
# Degree : 1
#
#
# Differentiate with respect to: s94 and s24
# Result After Differentiation:
# s79
# Degree : 1
#
#
# Differentiate with respect to: s94 and s56
# Result After Differentiation:
# s109
# Degree : 1
#
#
# Differentiate with respect to: s94 and s71
# Result After Differentiation:
# s79
# Degree : 1
#
#
# Differentiate with respect to: s94 and s79
# Result After Differentiation:
# s24 + s71 + s109 + s115 + k24 + 1
# Degree : 1
#
#
# Differentiate with respect to: s94 and s100
# Result After Differentiation:
# s109
# Degree : 1
#
#
# Differentiate with respect to: s94 and s109
# Result After Differentiation:
# s9 + s56 + s79 + s100 + k9 + 1
# Degree : 1
#
#
# Differentiate with respect to: s94 and s115
# Result After Differentiation:
# s79
# Degree : 1
#
#
# Differentiate with respect to: s100 and s94
# Result After Differentiation:
# s109
# Degree : 1
#
#
# Differentiate with respect to: s100 and s109
# Result After Differentiation:
# s94
# Degree : 1
#
#
# Differentiate with respect to: s109 and s9
# Result After Differentiation:
# s94
# Degree : 1
#
#
# Differentiate with respect to: s109 and s56
# Result After Differentiation:
# s94
# Degree : 1
#
#
# Differentiate with respect to: s109 and s79
# Result After Differentiation:
# s94
# Degree : 1
#
#
# Differentiate with respect to: s109 and s94
# Result After Differentiation:
# s9 + s56 + s79 + s100 + k9 + 1
# Degree : 1
#
#
# Differentiate with respect to: s109 and s100
# Result After Differentiation:
# s94
# Degree : 1
#
#
# Differentiate with respect to: s115 and s79
# Result After Differentiation:
# s94
# Degree : 1
#
#
# Differentiate with respect to: s115 and s94
# Result After Differentiation:
# s79
# Degree : 1
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 68
#
#
# Differentiate with respect to: s10 and s95
# Result After Differentiation:
# s110
# Degree : 1
#
#
# Differentiate with respect to: s10 and s110
# Result After Differentiation:
# s95
# Degree : 1
#
#
# Differentiate with respect to: s25 and s80
# Result After Differentiation:
# s95
# Degree : 1
#
#
# Differentiate with respect to: s25 and s95
# Result After Differentiation:
# s80
# Degree : 1
#
#
# Differentiate with respect to: s57 and s95
# Result After Differentiation:
# s110
# Degree : 1
#
#
# Differentiate with respect to: s57 and s110
# Result After Differentiation:
# s95
# Degree : 1
#
#
# Differentiate with respect to: s72 and s80
# Result After Differentiation:
# s95
# Degree : 1
#
#
# Differentiate with respect to: s72 and s95
# Result After Differentiation:
# s80
# Degree : 1
#
#
# Differentiate with respect to: s80 and s25
# Result After Differentiation:
# s95
# Degree : 1
#
#
# Differentiate with respect to: s80 and s72
# Result After Differentiation:
# s95
# Degree : 1
#
#
# Differentiate with respect to: s80 and s95
# Result After Differentiation:
# s25 + s72 + s110 + s116 + k25 + 1
# Degree : 1
#
#
# Differentiate with respect to: s80 and s110
# Result After Differentiation:
# s95
# Degree : 1
#
#
# Differentiate with respect to: s80 and s116
# Result After Differentiation:
# s95
# Degree : 1
#
#
# Differentiate with respect to: s95 and s10
# Result After Differentiation:
# s110
# Degree : 1
#
#
# Differentiate with respect to: s95 and s25
# Result After Differentiation:
# s80
# Degree : 1
#
#
# Differentiate with respect to: s95 and s57
# Result After Differentiation:
# s110
# Degree : 1
#
#
# Differentiate with respect to: s95 and s72
# Result After Differentiation:
# s80
# Degree : 1
#
#
# Differentiate with respect to: s95 and s80
# Result After Differentiation:
# s25 + s72 + s110 + s116 + k25 + 1
# Degree : 1
#
#
# Differentiate with respect to: s95 and s101
# Result After Differentiation:
# s110
# Degree : 1
#
#
# Differentiate with respect to: s95 and s110
# Result After Differentiation:
# s10 + s57 + s80 + s101 + k10 + 1
# Degree : 1
#
#
# Differentiate with respect to: s95 and s116
# Result After Differentiation:
# s80
# Degree : 1
#
#
# Differentiate with respect to: s101 and s95
# Result After Differentiation:
# s110
# Degree : 1
#
#
# Differentiate with respect to: s101 and s110
# Result After Differentiation:
# s95
# Degree : 1
#
#
# Differentiate with respect to: s110 and s10
# Result After Differentiation:
# s95
# Degree : 1
#
#
# Differentiate with respect to: s110 and s57
# Result After Differentiation:
# s95
# Degree : 1
#
#
# Differentiate with respect to: s110 and s80
# Result After Differentiation:
# s95
# Degree : 1
#
#
# Differentiate with respect to: s110 and s95
# Result After Differentiation:
# s10 + s57 + s80 + s101 + k10 + 1
# Degree : 1
#
#
# Differentiate with respect to: s110 and s101
# Result After Differentiation:
# s95
# Degree : 1
#
#
# Differentiate with respect to: s116 and s80
# Result After Differentiation:
# s95
# Degree : 1
#
#
# Differentiate with respect to: s116 and s95
# Result After Differentiation:
# s80
# Degree : 1
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 69
#
#
# Differentiate with respect to: s11 and s96
# Result After Differentiation:
# s111
# Degree : 1
#
#
# Differentiate with respect to: s11 and s111
# Result After Differentiation:
# s96
# Degree : 1
#
#
# Differentiate with respect to: s26 and s81
# Result After Differentiation:
# s96
# Degree : 1
#
#
# Differentiate with respect to: s26 and s96
# Result After Differentiation:
# s81
# Degree : 1
#
#
# Differentiate with respect to: s58 and s96
# Result After Differentiation:
# s111
# Degree : 1
#
#
# Differentiate with respect to: s58 and s111
# Result After Differentiation:
# s96
# Degree : 1
# Differentiate with respect to: s73 and s81
# Result After Differentiation:
# s96
# Degree : 1
#
#
# Differentiate with respect to: s73 and s96
# Result After Differentiation:
# s81
# Degree : 1
#
#
# Differentiate with respect to: s81 and s26
# Result After Differentiation:
# s96
# Degree : 1
#
#
# Differentiate with respect to: s81 and s73
# Result After Differentiation:
# s96
# Degree : 1
#
#
# Differentiate with respect to: s81 and s96
# Result After Differentiation:
# s26 + s73 + s111 + s117 + k26 + 1
# Degree : 1
#
#
# Differentiate with respect to: s81 and s111
# Result After Differentiation:
# s96
# Degree : 1
#
#
# Differentiate with respect to: s81 and s117
# Result After Differentiation:
# s96
# Degree : 1
#
#
# Differentiate with respect to: s96 and s11
# Result After Differentiation:
# s111
# Degree : 1
#
#
# Differentiate with respect to: s96 and s26
# Result After Differentiation:
# s81
# Degree : 1
#
#
# Differentiate with respect to: s96 and s58
# Result After Differentiation:
# s111
# Degree : 1
#
#
# Differentiate with respect to: s96 and s73
# Result After Differentiation:
# s81
# Degree : 1
#
#
# Differentiate with respect to: s96 and s81
# Result After Differentiation:
# s26 + s73 + s111 + s117 + k26 + 1
# Degree : 1
#
#
# Differentiate with respect to: s96 and s102
# Result After Differentiation:
# s111
# Degree : 1
#
#
# Differentiate with respect to: s96 and s111
# Result After Differentiation:
# s11 + s58 + s81 + s102 + k11 + 1
# Degree : 1
#
#
# Differentiate with respect to: s96 and s117
# Result After Differentiation:
# s81
# Degree : 1
#
#
# Differentiate with respect to: s102 and s96
# Result After Differentiation:
# s111
# Degree : 1
#
#
# Differentiate with respect to: s102 and s111
# Result After Differentiation:
# s96
# Degree : 1
#
#
# Differentiate with respect to: s111 and s11
# Result After Differentiation:
# s96
# Degree : 1
#
#
# Differentiate with respect to: s111 and s58
# Result After Differentiation:
# s96
# Degree : 1
#
#
# Differentiate with respect to: s111 and s81
# Result After Differentiation:
# s96
# Degree : 1
#
#
# Differentiate with respect to: s111 and s96
# Result After Differentiation:
# s11 + s58 + s81 + s102 + k11 + 1
# Degree : 1
#
#
# Differentiate with respect to: s111 and s102
# Result After Differentiation:
# s96
# Degree : 1
#
#
# Differentiate with respect to: s117 and s81
# Result After Differentiation:
# s96
# Degree : 1
#
#
# Differentiate with respect to: s117 and s96
# Result After Differentiation:
# s81
# Degree : 1
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 70
#
#
# Differentiate with respect to: s12 and s97
# Result After Differentiation:
# s112
# Degree : 1
#
#
# Differentiate with respect to: s12 and s112
# Result After Differentiation:
# s97
# Degree : 1
#
#
# Differentiate with respect to: s27 and s82
# Result After Differentiation:
# s97
# Degree : 1
#
#
# Differentiate with respect to: s27 and s97
# Result After Differentiation:
# s82
# Degree : 1
#
#
# Differentiate with respect to: s59 and s97
# Result After Differentiation:
# s112
# Degree : 1
#
#
# Differentiate with respect to: s59 and s112
# Result After Differentiation:
# s97
# Degree : 1
#
#
# Differentiate with respect to: s74 and s82
# Result After Differentiation:
# s97
# Degree : 1
#
#
# Differentiate with respect to: s74 and s97
# Result After Differentiation:
# s82
# Degree : 1
#
#
# Differentiate with respect to: s82 and s27
# Result After Differentiation:
# s97
# Degree : 1
#
#
# Differentiate with respect to: s82 and s74
# Result After Differentiation:
# s97
# Degree : 1
#
#
# Differentiate with respect to: s82 and s97
# Result After Differentiation:
# s27 + s74 + s112 + s118 + k27 + 1
# Degree : 1
#
#
# Differentiate with respect to: s82 and s112
# Result After Differentiation:
# s97
# Degree : 1
#
#
# Differentiate with respect to: s82 and s118
# Result After Differentiation:
# s97
# Degree : 1
#
#
# Differentiate with respect to: s97 and s12
# Result After Differentiation:
# s112
# Degree : 1
#
#
# Differentiate with respect to: s97 and s27
# Result After Differentiation:
# s82
# Degree : 1
#
#
# Differentiate with respect to: s97 and s59
# Result After Differentiation:
# s112
# Degree : 1
#
#
# Differentiate with respect to: s97 and s74
# Result After Differentiation:
# s82
# Degree : 1
#
#
# Differentiate with respect to: s97 and s82
# Result After Differentiation:
# s27 + s74 + s112 + s118 + k27 + 1
# Degree : 1
#
#
# Differentiate with respect to: s97 and s103
# Result After Differentiation:
# s112
# Degree : 1
#
#
# Differentiate with respect to: s97 and s112
# Result After Differentiation:
# s12 + s59 + s82 + s103 + k12 + 1
# Degree : 1
#
#
# Differentiate with respect to: s97 and s118
# Result After Differentiation:
# s82
# Degree : 1
#
#
# Differentiate with respect to: s103 and s97
# Result After Differentiation:
# s112
# Degree : 1
#
#
# Differentiate with respect to: s103 and s112
# Result After Differentiation:
# s97
# Degree : 1
#
#
# Differentiate with respect to: s112 and s12
# Result After Differentiation:
# s97
# Degree : 1
#
#
# Differentiate with respect to: s112 and s59
# Result After Differentiation:
# s97
# Degree : 1
#
#
# Differentiate with respect to: s112 and s82
# Result After Differentiation:
# s97
# Degree : 1
#
#
# Differentiate with respect to: s112 and s97
# Result After Differentiation:
# s12 + s59 + s82 + s103 + k12 + 1
# Degree : 1
#
#
# Differentiate with respect to: s112 and s103
# Result After Differentiation:
# s97
# Degree : 1
#
#
# Differentiate with respect to: s118 and s82
# Result After Differentiation:
# s97
# Degree : 1
#
#
# Differentiate with respect to: s118 and s97
# Result After Differentiation:
# s82
# Degree : 1
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 71
#
#
# Differentiate with respect to: s13 and s98
# Result After Differentiation:
# s113
# Degree : 1
#
#
# Differentiate with respect to: s13 and s113
# Result After Differentiation:
# s98
# Degree : 1
#
#
# Differentiate with respect to: s28 and s83
# Result After Differentiation:
# s98
# Degree : 1
#
#
# Differentiate with respect to: s28 and s98
# Result After Differentiation:
# s83
# Degree : 1
#
#
# Differentiate with respect to: s60 and s98
# Result After Differentiation:
# s113
# Degree : 1
#
#
# Differentiate with respect to: s60 and s113
# Result After Differentiation:
# s98
# Degree : 1
#
#
# Differentiate with respect to: s75 and s83
# Result After Differentiation:
# s98
# Degree : 1
#
#
# Differentiate with respect to: s75 and s98
# Result After Differentiation:
# s83
# Degree : 1
#
#
# Differentiate with respect to: s83 and s28
# Result After Differentiation:
# s98
# Degree : 1
#
#
# Differentiate with respect to: s83 and s75
# Result After Differentiation:
# s98
# Degree : 1
#
#
# Differentiate with respect to: s83 and s98
# Result After Differentiation:
# s28 + s75 + s113 + s119 + k28 + 1
# Degree : 1
#
#
# Differentiate with respect to: s83 and s113
# Result After Differentiation:
# s98
# Degree : 1
#
#
# Differentiate with respect to: s83 and s119
# Result After Differentiation:
# s98
# Degree : 1
#
#
# Differentiate with respect to: s98 and s13
# Result After Differentiation:
# s113
# Degree : 1
#
#
# Differentiate with respect to: s98 and s28
# Result After Differentiation:
# s83
# Degree : 1
#
#
# Differentiate with respect to: s98 and s60
# Result After Differentiation:
# s113
# Degree : 1
#
#
# Differentiate with respect to: s98 and s75
# Result After Differentiation:
# s83
# Degree : 1
#
#
# Differentiate with respect to: s98 and s83
# Result After Differentiation:
# s28 + s75 + s113 + s119 + k28 + 1
# Degree : 1
#
#
# Differentiate with respect to: s98 and s104
# Result After Differentiation:
# s113
# Degree : 1
#
#
# Differentiate with respect to: s98 and s113
# Result After Differentiation:
# s13 + s60 + s83 + s104 + k13 + 1
# Degree : 1
#
#
# Differentiate with respect to: s98 and s119
# Result After Differentiation:
# s83
# Degree : 1
#
#
# Differentiate with respect to: s104 and s98
# Result After Differentiation:
# s113
# Degree : 1
#
#
# Differentiate with respect to: s104 and s113
# Result After Differentiation:
# s98
# Degree : 1
#
#
# Differentiate with respect to: s113 and s13
# Result After Differentiation:
# s98
# Degree : 1
#
#
# Differentiate with respect to: s113 and s60
# Result After Differentiation:
# s98
# Degree : 1
#
#
# Differentiate with respect to: s113 and s83
# Result After Differentiation:
# s98
# Degree : 1
#
#
# Differentiate with respect to: s113 and s98
# Result After Differentiation:
# s13 + s60 + s83 + s104 + k13 + 1
# Degree : 1
#
#
# Differentiate with respect to: s113 and s104
# Result After Differentiation:
# s98
# Degree : 1
#
#
# Differentiate with respect to: s119 and s83
# Result After Differentiation:
# s98
# Degree : 1
#
#
# Differentiate with respect to: s119 and s98
# Result After Differentiation:
# s83
# Degree : 1
# --------------------------------------------------------------------------------------------------------------
# S = 72
#
#
# Differentiate with respect to: s14 and s99
# Result After Differentiation:
# s114
# Degree : 1
#
#
# Differentiate with respect to: s14 and s114
# Result After Differentiation:
# s99
# Degree : 1
#
#
# Differentiate with respect to: s29 and s84
# Result After Differentiation:
# s99
# Degree : 1
#
#
# Differentiate with respect to: s29 and s99
# Result After Differentiation:
# s84
# Degree : 1
#
#
# Differentiate with respect to: s61 and s99
# Result After Differentiation:
# s114
# Degree : 1
#
#
# Differentiate with respect to: s61 and s114
# Result After Differentiation:
# s99
# Degree : 1
#
#
# Differentiate with respect to: s76 and s84
# Result After Differentiation:
# s99
# Degree : 1
#
#
# Differentiate with respect to: s76 and s99
# Result After Differentiation:
# s84
# Degree : 1
#
#
# Differentiate with respect to: s84 and s29
# Result After Differentiation:
# s99
# Degree : 1
#
#
# Differentiate with respect to: s84 and s76
# Result After Differentiation:
# s99
# Degree : 1
#
#
# Differentiate with respect to: s84 and s99
# Result After Differentiation:
# s29 + s76 + s114 + s120 + k29 + 1
# Degree : 1
#
#
# Differentiate with respect to: s84 and s114
# Result After Differentiation:
# s99
# Degree : 1
#
#
# Differentiate with respect to: s84 and s120
# Result After Differentiation:
# s99
# Degree : 1
#
#
# Differentiate with respect to: s99 and s14
# Result After Differentiation:
# s114
# Degree : 1
#
#
# Differentiate with respect to: s99 and s29
# Result After Differentiation:
# s84
# Degree : 1
#
#
# Differentiate with respect to: s99 and s61
# Result After Differentiation:
# s114
# Degree : 1
#
#
# Differentiate with respect to: s99 and s76
# Result After Differentiation:
# s84
# Degree : 1
#
#
# Differentiate with respect to: s99 and s84
# Result After Differentiation:
# s29 + s76 + s114 + s120 + k29 + 1
# Degree : 1
#
#
# Differentiate with respect to: s99 and s105
# Result After Differentiation:
# s114
# Degree : 1
#
#
# Differentiate with respect to: s99 and s114
# Result After Differentiation:
# s14 + s61 + s84 + s105 + k14 + 1
# Degree : 1
#
#
# Differentiate with respect to: s99 and s120
# Result After Differentiation:
# s84
# Degree : 1
#
#
# Differentiate with respect to: s105 and s99
# Result After Differentiation:
# s114
# Degree : 1
#
#
# Differentiate with respect to: s105 and s114
# Result After Differentiation:
# s99
# Degree : 1
#
#
# Differentiate with respect to: s114 and s14
# Result After Differentiation:
# s99
# Degree : 1
#
#
# Differentiate with respect to: s114 and s61
# Result After Differentiation:
# s99
# Degree : 1
#
#
# Differentiate with respect to: s114 and s84
# Result After Differentiation:
# s99
# Degree : 1
#
#
# Differentiate with respect to: s114 and s99
# Result After Differentiation:
# s14 + s61 + s84 + s105 + k14 + 1
# Degree : 1
#
#
# Differentiate with respect to: s114 and s105
# Result After Differentiation:
# s99
# Degree : 1
#
#
# Differentiate with respect to: s120 and s84
# Result After Differentiation:
# s99
# Degree : 1
#
#
# Differentiate with respect to: s120 and s99
# Result After Differentiation:
# s84
# Degree : 1
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 73
#
#
# Differentiate with respect to: s15 and s100
# Result After Differentiation:
# s115
# Degree : 1
#
#
# Differentiate with respect to: s15 and s115
# Result After Differentiation:
# s100
# Degree : 1
#
#
# Differentiate with respect to: s30 and s85
# Result After Differentiation:
# s100
# Degree : 1
#
#
# Differentiate with respect to: s30 and s100
# Result After Differentiation:
# s85
# Degree : 1
#
#
# Differentiate with respect to: s62 and s100
# Result After Differentiation:
# s115
# Degree : 1
#
#
# Differentiate with respect to: s62 and s115
# Result After Differentiation:
# s100
# Degree : 1
#
#
# Differentiate with respect to: s77 and s85
# Result After Differentiation:
# s100
# Degree : 1
#
#
# Differentiate with respect to: s77 and s100
# Result After Differentiation:
# s85
# Degree : 1
#
#
# Differentiate with respect to: s85 and s30
# Result After Differentiation:
# s100
# Degree : 1
#
#
# Differentiate with respect to: s85 and s77
# Result After Differentiation:
# s100
# Degree : 1
#
#
# Differentiate with respect to: s85 and s100
# Result After Differentiation:
# s30 + s77 + s115 + s121 + k30 + 1
# Degree : 1
#
#
# Differentiate with respect to: s85 and s115
# Result After Differentiation:
# s100
# Degree : 1
#
#
# Differentiate with respect to: s85 and s121
# Result After Differentiation:
# s100
# Degree : 1
#
#
# Differentiate with respect to: s100 and s15
# Result After Differentiation:
# s115
# Degree : 1
#
#
# Differentiate with respect to: s100 and s30
# Result After Differentiation:
# s85
# Degree : 1
#
#
# Differentiate with respect to: s100 and s62
# Result After Differentiation:
# s115
# Degree : 1
#
#
# Differentiate with respect to: s100 and s77
# Result After Differentiation:
# s85
# Degree : 1
#
#
# Differentiate with respect to: s100 and s85
# Result After Differentiation:
# s30 + s77 + s115 + s121 + k30 + 1
# Degree : 1
#
#
# Differentiate with respect to: s100 and s106
# Result After Differentiation:
# s115
# Degree : 1
#
#
# Differentiate with respect to: s100 and s115
# Result After Differentiation:
# s15 + s62 + s85 + s106 + k15 + 1
# Degree : 1
#
#
# Differentiate with respect to: s100 and s121
# Result After Differentiation:
# s85
# Degree : 1
#
#
# Differentiate with respect to: s106 and s100
# Result After Differentiation:
# s115
# Degree : 1
#
#
# Differentiate with respect to: s106 and s115
# Result After Differentiation:
# s100
# Degree : 1
#
#
# Differentiate with respect to: s115 and s15
# Result After Differentiation:
# s100
# Degree : 1
#
#
# Differentiate with respect to: s115 and s62
# Result After Differentiation:
# s100
# Degree : 1
#
#
# Differentiate with respect to: s115 and s85
# Result After Differentiation:
# s100
# Degree : 1
#
#
# Differentiate with respect to: s115 and s100
# Result After Differentiation:
# s15 + s62 + s85 + s106 + k15 + 1
# Degree : 1
#
#
# Differentiate with respect to: s115 and s106
# Result After Differentiation:
# s100
# Degree : 1
#
#
# Differentiate with respect to: s121 and s85
# Result After Differentiation:
# s100
# Degree : 1
#
#
# Differentiate with respect to: s121 and s100
# Result After Differentiation:
# s85
# Degree : 1
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 74
#
#
# Differentiate with respect to: s16 and s101
# Result After Differentiation:
# s116
# Degree : 1
#
#
# Differentiate with respect to: s16 and s116
# Result After Differentiation:
# s101
# Degree : 1
#
#
# Differentiate with respect to: s31 and s86
# Result After Differentiation:
# s101
# Degree : 1
#
#
# Differentiate with respect to: s31 and s101
# Result After Differentiation:
# s86
# Degree : 1
#
#
# Differentiate with respect to: s63 and s101
# Result After Differentiation:
# s116
# Degree : 1
#
#
# Differentiate with respect to: s63 and s116
# Result After Differentiation:
# s101
# Degree : 1
#
#
# Differentiate with respect to: s78 and s86
# Result After Differentiation:
# s101
# Degree : 1
#
#
# Differentiate with respect to: s78 and s101
# Result After Differentiation:
# s86
# Degree : 1
#
#
# Differentiate with respect to: s86 and s31
# Result After Differentiation:
# s101
# Degree : 1
#
#
# Differentiate with respect to: s86 and s78
# Result After Differentiation:
# s101
# Degree : 1
#
#
# Differentiate with respect to: s86 and s101
# Result After Differentiation:
# s31 + s78 + s116 + s122 + k31 + 1
# Degree : 1
#
#
# Differentiate with respect to: s86 and s116
# Result After Differentiation:
# s101
# Degree : 1
#
#
# Differentiate with respect to: s86 and s122
# Result After Differentiation:
# s101
# Degree : 1
#
#
# Differentiate with respect to: s101 and s16
# Result After Differentiation:
# s116
# Degree : 1
#
#
# Differentiate with respect to: s101 and s31
# Result After Differentiation:
# s86
# Degree : 1
#
#
# Differentiate with respect to: s101 and s63
# Result After Differentiation:
# s116
# Degree : 1
#
#
# Differentiate with respect to: s101 and s78
# Result After Differentiation:
# s86
# Degree : 1
#
#
# Differentiate with respect to: s101 and s86
# Result After Differentiation:
# s31 + s78 + s116 + s122 + k31 + 1
# Degree : 1
#
#
# Differentiate with respect to: s101 and s107
# Result After Differentiation:
# s116
# Degree : 1
#
#
# Differentiate with respect to: s101 and s116
# Result After Differentiation:
# s16 + s63 + s86 + s107 + k16 + 1
# Degree : 1
#
#
# Differentiate with respect to: s101 and s122
# Result After Differentiation:
# s86
# Degree : 1
#
#
# Differentiate with respect to: s107 and s101
# Result After Differentiation:
# s116
# Degree : 1
#
#
# Differentiate with respect to: s107 and s116
# Result After Differentiation:
# s101
# Degree : 1
# Differentiate with respect to: s116 and s16
# Result After Differentiation:
# s101
# Degree : 1
#
#
# Differentiate with respect to: s116 and s63
# Result After Differentiation:
# s101
# Degree : 1
#
#
# Differentiate with respect to: s116 and s86
# Result After Differentiation:
# s101
# Degree : 1
#
#
# Differentiate with respect to: s116 and s101
# Result After Differentiation:
# s16 + s63 + s86 + s107 + k16 + 1
# Degree : 1
#
#
# Differentiate with respect to: s116 and s107
# Result After Differentiation:
# s101
# Degree : 1
#
#
# Differentiate with respect to: s122 and s86
# Result After Differentiation:
# s101
# Degree : 1
#
#
# Differentiate with respect to: s122 and s101
# Result After Differentiation:
# s86
# Degree : 1
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 75
#
#
# Differentiate with respect to: s17 and s102
# Result After Differentiation:
# s117
# Degree : 1
#
#
# Differentiate with respect to: s17 and s117
# Result After Differentiation:
# s102
# Degree : 1
#
#
# Differentiate with respect to: s32 and s87
# Result After Differentiation:
# s102
# Degree : 1
#
#
# Differentiate with respect to: s32 and s102
# Result After Differentiation:
# s87
# Degree : 1
#
#
# Differentiate with respect to: s64 and s102
# Result After Differentiation:
# s117
# Degree : 1
#
#
# Differentiate with respect to: s64 and s117
# Result After Differentiation:
# s102
# Degree : 1
#
#
# Differentiate with respect to: s79 and s87
# Result After Differentiation:
# s102
# Degree : 1
#
#
# Differentiate with respect to: s79 and s102
# Result After Differentiation:
# s87
# Degree : 1
#
#
# Differentiate with respect to: s87 and s32
# Result After Differentiation:
# s102
# Degree : 1
#
#
# Differentiate with respect to: s87 and s79
# Result After Differentiation:
# s102
# Degree : 1
#
#
# Differentiate with respect to: s87 and s102
# Result After Differentiation:
# s32 + s79 + s117 + s123 + k32 + 1
# Degree : 1
#
#
# Differentiate with respect to: s87 and s117
# Result After Differentiation:
# s102
# Degree : 1
#
#
# Differentiate with respect to: s87 and s123
# Result After Differentiation:
# s102
# Degree : 1
#
#
# Differentiate with respect to: s102 and s17
# Result After Differentiation:
# s117
# Degree : 1
#
#
# Differentiate with respect to: s102 and s32
# Result After Differentiation:
# s87
# Degree : 1
#
#
# Differentiate with respect to: s102 and s64
# Result After Differentiation:
# s117
# Degree : 1
#
#
# Differentiate with respect to: s102 and s79
# Result After Differentiation:
# s87
# Degree : 1
#
#
# Differentiate with respect to: s102 and s87
# Result After Differentiation:
# s32 + s79 + s117 + s123 + k32 + 1
# Degree : 1
#
#
# Differentiate with respect to: s102 and s108
# Result After Differentiation:
# s117
# Degree : 1
#
#
# Differentiate with respect to: s102 and s117
# Result After Differentiation:
# s17 + s64 + s87 + s108 + k17 + 1
# Degree : 1
#
#
# Differentiate with respect to: s102 and s123
# Result After Differentiation:
# s87
# Degree : 1
#
#
# Differentiate with respect to: s108 and s102
# Result After Differentiation:
# s117
# Degree : 1
#
#
# Differentiate with respect to: s108 and s117
# Result After Differentiation:
# s102
# Degree : 1
#
#
# Differentiate with respect to: s117 and s17
# Result After Differentiation:
# s102
# Degree : 1
#
#
# Differentiate with respect to: s117 and s64
# Result After Differentiation:
# s102
# Degree : 1
#
#
# Differentiate with respect to: s117 and s87
# Result After Differentiation:
# s102
# Degree : 1
#
#
# Differentiate with respect to: s117 and s102
# Result After Differentiation:
# s17 + s64 + s87 + s108 + k17 + 1
# Degree : 1
#
#
# Differentiate with respect to: s117 and s108
# Result After Differentiation:
# s102
# Degree : 1
#
#
# Differentiate with respect to: s123 and s87
# Result After Differentiation:
# s102
# Degree : 1
#
#
# Differentiate with respect to: s123 and s102
# Result After Differentiation:
# s87
# Degree : 1
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 76
#
#
# Differentiate with respect to: s18 and s103
# Result After Differentiation:
# s118
# Degree : 1
#
#
# Differentiate with respect to: s18 and s118
# Result After Differentiation:
# s103
# Degree : 1
#
#
# Differentiate with respect to: s33 and s88
# Result After Differentiation:
# s103
# Degree : 1
#
#
# Differentiate with respect to: s33 and s103
# Result After Differentiation:
# s88
# Degree : 1
#
#
# Differentiate with respect to: s65 and s103
# Result After Differentiation:
# s118
# Degree : 1
#
#
# Differentiate with respect to: s65 and s118
# Result After Differentiation:
# s103
# Degree : 1
#
#
# Differentiate with respect to: s80 and s88
# Result After Differentiation:
# s103
# Degree : 1
#
#
# Differentiate with respect to: s80 and s103
# Result After Differentiation:
# s88
# Degree : 1
#
#
# Differentiate with respect to: s88 and s33
# Result After Differentiation:
# s103
# Degree : 1
#
#
# Differentiate with respect to: s88 and s80
# Result After Differentiation:
# s103
# Degree : 1
#
#
# Differentiate with respect to: s88 and s103
# Result After Differentiation:
# s33 + s80 + s118 + s124 + k33 + 1
# Degree : 1
#
#
# Differentiate with respect to: s88 and s118
# Result After Differentiation:
# s103
# Degree : 1
#
#
# Differentiate with respect to: s88 and s124
# Result After Differentiation:
# s103
# Degree : 1
#
#
# Differentiate with respect to: s103 and s18
# Result After Differentiation:
# s118
# Degree : 1
#
#
# Differentiate with respect to: s103 and s33
# Result After Differentiation:
# s88
# Degree : 1
#
#
# Differentiate with respect to: s103 and s65
# Result After Differentiation:
# s118
# Degree : 1
#
#
# Differentiate with respect to: s103 and s80
# Result After Differentiation:
# s88
# Degree : 1
#
#
# Differentiate with respect to: s103 and s88
# Result After Differentiation:
# s33 + s80 + s118 + s124 + k33 + 1
# Degree : 1
#
#
# Differentiate with respect to: s103 and s109
# Result After Differentiation:
# s118
# Degree : 1
#
#
# Differentiate with respect to: s103 and s118
# Result After Differentiation:
# s18 + s65 + s88 + s109 + k18 + 1
# Degree : 1
#
#
# Differentiate with respect to: s103 and s124
# Result After Differentiation:
# s88
# Degree : 1
#
#
# Differentiate with respect to: s109 and s103
# Result After Differentiation:
# s118
# Degree : 1
#
#
# Differentiate with respect to: s109 and s118
# Result After Differentiation:
# s103
# Degree : 1
#
#
# Differentiate with respect to: s118 and s18
# Result After Differentiation:
# s103
# Degree : 1
#
#
# Differentiate with respect to: s118 and s65
# Result After Differentiation:
# s103
# Degree : 1
#
#
# Differentiate with respect to: s118 and s88
# Result After Differentiation:
# s103
# Degree : 1
#
#
# Differentiate with respect to: s118 and s103
# Result After Differentiation:
# s18 + s65 + s88 + s109 + k18 + 1
# Degree : 1
#
#
# Differentiate with respect to: s118 and s109
# Result After Differentiation:
# s103
# Degree : 1
#
#
# Differentiate with respect to: s124 and s88
# Result After Differentiation:
# s103
# Degree : 1
#
#
# Differentiate with respect to: s124 and s103
# Result After Differentiation:
# s88
# Degree : 1
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 77
#
#
# Differentiate with respect to: s19 and s104
# Result After Differentiation:
# s119
# Degree : 1
#
#
# Differentiate with respect to: s19 and s119
# Result After Differentiation:
# s104
# Degree : 1
#
#
# Differentiate with respect to: s34 and s89
# Result After Differentiation:
# s104
# Degree : 1
#
#
# Differentiate with respect to: s34 and s104
# Result After Differentiation:
# s89
# Degree : 1
#
#
# Differentiate with respect to: s66 and s104
# Result After Differentiation:
# s119
# Degree : 1
#
#
# Differentiate with respect to: s66 and s119
# Result After Differentiation:
# s104
# Degree : 1
#
#
# Differentiate with respect to: s81 and s89
# Result After Differentiation:
# s104
# Degree : 1
#
#
# Differentiate with respect to: s81 and s104
# Result After Differentiation:
# s89
# Degree : 1
#
#
# Differentiate with respect to: s89 and s34
# Result After Differentiation:
# s104
# Degree : 1
#
#
# Differentiate with respect to: s89 and s81
# Result After Differentiation:
# s104
# Degree : 1
#
#
# Differentiate with respect to: s89 and s104
# Result After Differentiation:
# s34 + s81 + s119 + s125 + k34 + 1
# Degree : 1
#
#
# Differentiate with respect to: s89 and s119
# Result After Differentiation:
# s104
# Degree : 1
#
#
# Differentiate with respect to: s89 and s125
# Result After Differentiation:
# s104
# Degree : 1
#
#
# Differentiate with respect to: s104 and s19
# Result After Differentiation:
# s119
# Degree : 1
#
#
# Differentiate with respect to: s104 and s34
# Result After Differentiation:
# s89
# Degree : 1
#
#
# Differentiate with respect to: s104 and s66
# Result After Differentiation:
# s119
# Degree : 1
#
#
# Differentiate with respect to: s104 and s81
# Result After Differentiation:
# s89
# Degree : 1
#
#
# Differentiate with respect to: s104 and s89
# Result After Differentiation:
# s34 + s81 + s119 + s125 + k34 + 1
# Degree : 1
#
#
# Differentiate with respect to: s104 and s110
# Result After Differentiation:
# s119
# Degree : 1
#
#
# Differentiate with respect to: s104 and s119
# Result After Differentiation:
# s19 + s66 + s89 + s110 + k19 + 1
# Degree : 1
#
#
# Differentiate with respect to: s104 and s125
# Result After Differentiation:
# s89
# Degree : 1
# Differentiate with respect to: s110 and s104
# Result After Differentiation:
# s119
# Degree : 1
#
#
# Differentiate with respect to: s110 and s119
# Result After Differentiation:
# s104
# Degree : 1
#
#
# Differentiate with respect to: s119 and s19
# Result After Differentiation:
# s104
# Degree : 1
#
#
# Differentiate with respect to: s119 and s66
# Result After Differentiation:
# s104
# Degree : 1
#
#
# Differentiate with respect to: s119 and s89
# Result After Differentiation:
# s104
# Degree : 1
#
#
# Differentiate with respect to: s119 and s104
# Result After Differentiation:
# s19 + s66 + s89 + s110 + k19 + 1
# Degree : 1
#
#
# Differentiate with respect to: s119 and s110
# Result After Differentiation:
# s104
# Degree : 1
#
#
# Differentiate with respect to: s125 and s89
# Result After Differentiation:
# s104
# Degree : 1
#
#
# Differentiate with respect to: s125 and s104
# Result After Differentiation:
# s89
# Degree : 1
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 78
#
#
# Differentiate with respect to: s20 and s105
# Result After Differentiation:
# s120
# Degree : 1
#
#
# Differentiate with respect to: s20 and s120
# Result After Differentiation:
# s105
# Degree : 1
#
#
# Differentiate with respect to: s35 and s90
# Result After Differentiation:
# s105
# Degree : 1
#
#
# Differentiate with respect to: s35 and s105
# Result After Differentiation:
# s90
# Degree : 1
#
#
# Differentiate with respect to: s67 and s105
# Result After Differentiation:
# s120
# Degree : 1
#
#
# Differentiate with respect to: s67 and s120
# Result After Differentiation:
# s105
# Degree : 1
#
#
# Differentiate with respect to: s82 and s90
# Result After Differentiation:
# s105
# Degree : 1
#
#
# Differentiate with respect to: s82 and s105
# Result After Differentiation:
# s90
# Degree : 1
#
#
# Differentiate with respect to: s90 and s35
# Result After Differentiation:
# s105
# Degree : 1
#
#
# Differentiate with respect to: s90 and s82
# Result After Differentiation:
# s105
# Degree : 1
#
#
# Differentiate with respect to: s90 and s105
# Result After Differentiation:
# s35 + s82 + s120 + s126 + k35 + 1
# Degree : 1
#
#
# Differentiate with respect to: s90 and s120
# Result After Differentiation:
# s105
# Degree : 1
#
#
# Differentiate with respect to: s90 and s126
# Result After Differentiation:
# s105
# Degree : 1
#
#
# Differentiate with respect to: s105 and s20
# Result After Differentiation:
# s120
# Degree : 1
#
#
# Differentiate with respect to: s105 and s35
# Result After Differentiation:
# s90
# Degree : 1
#
#
# Differentiate with respect to: s105 and s67
# Result After Differentiation:
# s120
# Degree : 1
#
#
# Differentiate with respect to: s105 and s82
# Result After Differentiation:
# s90
# Degree : 1
#
#
# Differentiate with respect to: s105 and s90
# Result After Differentiation:
# s35 + s82 + s120 + s126 + k35 + 1
# Degree : 1
#
#
# Differentiate with respect to: s105 and s111
# Result After Differentiation:
# s120
# Degree : 1
#
#
# Differentiate with respect to: s105 and s120
# Result After Differentiation:
# s20 + s67 + s90 + s111 + k20 + 1
# Degree : 1
#
#
# Differentiate with respect to: s105 and s126
# Result After Differentiation:
# s90
# Degree : 1
#
#
# Differentiate with respect to: s111 and s105
# Result After Differentiation:
# s120
# Degree : 1
#
#
# Differentiate with respect to: s111 and s120
# Result After Differentiation:
# s105
# Degree : 1
#
#
# Differentiate with respect to: s120 and s20
# Result After Differentiation:
# s105
# Degree : 1
#
#
# Differentiate with respect to: s120 and s67
# Result After Differentiation:
# s105
# Degree : 1
#
#
# Differentiate with respect to: s120 and s90
# Result After Differentiation:
# s105
# Degree : 1
#
#
# Differentiate with respect to: s120 and s105
# Result After Differentiation:
# s20 + s67 + s90 + s111 + k20 + 1
# Degree : 1
#
#
# Differentiate with respect to: s120 and s111
# Result After Differentiation:
# s105
# Degree : 1
#
#
# Differentiate with respect to: s126 and s90
# Result After Differentiation:
# s105
# Degree : 1
#
#
# Differentiate with respect to: s126 and s105
# Result After Differentiation:
# s90
# Degree : 1
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 79
#
#
# Differentiate with respect to: s21 and s106
# Result After Differentiation:
# s121
# Degree : 1
#
#
# Differentiate with respect to: s21 and s121
# Result After Differentiation:
# s106
# Degree : 1
#
#
# Differentiate with respect to: s36 and s91
# Result After Differentiation:
# s106
# Degree : 1
#
#
# Differentiate with respect to: s36 and s106
# Result After Differentiation:
# s91
# Degree : 1
#
#
# Differentiate with respect to: s68 and s106
# Result After Differentiation:
# s121
# Degree : 1
#
#
# Differentiate with respect to: s68 and s121
# Result After Differentiation:
# s106
# Degree : 1
#
#
# Differentiate with respect to: s83 and s91
# Result After Differentiation:
# s106
# Degree : 1
#
#
# Differentiate with respect to: s83 and s106
# Result After Differentiation:
# s91
# Degree : 1
#
#
# Differentiate with respect to: s91 and s36
# Result After Differentiation:
# s106
# Degree : 1
#
#
# Differentiate with respect to: s91 and s83
# Result After Differentiation:
# s106
# Degree : 1
#
#
# Differentiate with respect to: s91 and s106
# Result After Differentiation:
# s36 + s83 + s121 + s127 + k36 + 1
# Degree : 1
#
#
# Differentiate with respect to: s91 and s121
# Result After Differentiation:
# s106
# Degree : 1
#
#
# Differentiate with respect to: s91 and s127
# Result After Differentiation:
# s106
# Degree : 1
#
#
# Differentiate with respect to: s106 and s21
# Result After Differentiation:
# s121
# Degree : 1
#
#
# Differentiate with respect to: s106 and s36
# Result After Differentiation:
# s91
# Degree : 1
#
#
# Differentiate with respect to: s106 and s68
# Result After Differentiation:
# s121
# Degree : 1
#
#
# Differentiate with respect to: s106 and s83
# Result After Differentiation:
# s91
# Degree : 1
#
#
# Differentiate with respect to: s106 and s91
# Result After Differentiation:
# s36 + s83 + s121 + s127 + k36 + 1
# Degree : 1
#
#
# Differentiate with respect to: s106 and s112
# Result After Differentiation:
# s121
# Degree : 1
#
#
# Differentiate with respect to: s106 and s121
# Result After Differentiation:
# s21 + s68 + s91 + s112 + k21 + 1
# Degree : 1
#
#
# Differentiate with respect to: s106 and s127
# Result After Differentiation:
# s91
# Degree : 1
#
#
# Differentiate with respect to: s112 and s106
# Result After Differentiation:
# s121
# Degree : 1
#
#
# ...
# s121
# Degree : 1
#
#
# Differentiate with respect to: s106 and s51
# Result After Differentiation:
# s121
# Degree : 1
#
#
# Differentiate with respect to: s106 and s55
# Result After Differentiation:
# s121
# Degree : 1
#
#
# Differentiate with respect to: s106 and s61
# Result After Differentiation:
# s121
# Degree : 1
#
#
# Differentiate with respect to: s106 and s78
# Result After Differentiation:
# s93*s121
# Degree : 2
#
#
# Differentiate with respect to: s106 and s84
# Result After Differentiation:
# s99*s121
# Degree : 2
#
#
# Differentiate with respect to: s106 and s93
# Result After Differentiation:
# s78*s121
# Degree : 2
#
#
# Differentiate with respect to: s106 and s98
# Result After Differentiation:
# s121
# Degree : 1
#
#
# Differentiate with respect to: s106 and s99
# Result After Differentiation:
# s84*s121 + s121
# Degree : 2
#
#
# Differentiate with respect to: s106 and s105
# Result After Differentiation:
# s121
# Degree : 1
#
#
# Differentiate with respect to: s106 and s121
# Result After Differentiation:
# s8 + s14 + s51 + s55 + s61 + s78*s93 + s84*s99 + s98 + s99 + s105 + k8 + k14 + k51 + 1
# Degree : 2
#
#
# Differentiate with respect to: s121 and s8
# Result After Differentiation:
# s36 + s83 + s106 + s127 + k36 + 1
# Degree : 1
#
#
# Differentiate with respect to: s121 and s14
# Result After Differentiation:
# s106
# Degree : 1
#
#
# Differentiate with respect to: s121 and s36
# Result After Differentiation:
# s8 + s55 + s78*s93 + s99 + k8 + 1
# Degree : 2
#
#
# Differentiate with respect to: s121 and s51
# Result After Differentiation:
# s106
# Degree : 1
#
#
# Differentiate with respect to: s121 and s55
# Result After Differentiation:
# s36 + s83 + s106 + s127 + k36 + 1
# Degree : 1
#
#
# Differentiate with respect to: s121 and s61
# Result After Differentiation:
# s106
# Degree : 1
#
#
# Differentiate with respect to: s121 and s78
# Result After Differentiation:
# s36*s93 + s83*s93 + s93*s106 + s93*s127 + s93*k36 + s93
# Degree : 2
#
#
# Differentiate with respect to: s121 and s83
# Result After Differentiation:
# s8 + s55 + s78*s93 + s99 + k8 + 1
# Degree : 2
#
#
# Differentiate with respect to: s121 and s84
# Result After Differentiation:
# s99*s106
# Degree : 2
#
#
# Differentiate with respect to: s121 and s93
# Result After Differentiation:
# s36*s78 + s78*s83 + s78*s106 + s78*s127 + s78*k36 + s78
# Degree : 2
#
#
# Differentiate with respect to: s121 and s98
# Result After Differentiation:
# s106
# Degree : 1
#
#
# Differentiate with respect to: s121 and s99
# Result After Differentiation:
# s36 + s83 + s84*s106 + s106 + s127 + k36 + 1
# Degree : 2
#
#
# Differentiate with respect to: s121 and s105
# Result After Differentiation:
# s106
# Degree : 1
#
#
# Differentiate with respect to: s121 and s106
# Result After Differentiation:
# s8 + s14 + s51 + s55 + s61 + s78*s93 + s84*s99 + s98 + s99 + s105 + k8 + k14 + k51 + 1
# Degree : 2
#
#
# Differentiate with respect to: s121 and s127
# Result After Differentiation:
# s8 + s55 + s78*s93 + s99 + k8 + 1
# Degree : 2
#
#
# Differentiate with respect to: s127 and s8
# Result After Differentiation:
# s121
# Degree : 1
#
#
# Differentiate with respect to: s127 and s55
# Result After Differentiation:
# s121
# Degree : 1
#
#
# Differentiate with respect to: s127 and s78
# Result After Differentiation:
# s93*s121
# Degree : 2
#
#
# Differentiate with respect to: s127 and s93
# Result After Differentiation:
# s78*s121
# Degree : 2
#
#
# Differentiate with respect to: s127 and s99
# Result After Differentiation:
# s121
# Degree : 1
#
#
# Differentiate with respect to: s127 and s121
# Result After Differentiation:
# s8 + s55 + s78*s93 + s99 + k8 + 1
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 95
#
#
# Differentiate with respect to: s0 and s9
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s0 and s56
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s0 and s79
# Result After Differentiation:
# s94*s122
# Degree : 2
#
#
# Differentiate with respect to: s0 and s94
# Result After Differentiation:
# s79*s122
# Degree : 2
#
#
# Differentiate with respect to: s0 and s100
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s0 and s122
# Result After Differentiation:
# s9 + s56 + s79*s94 + s100 + k9 + 1
# Degree : 2
#
#
# Differentiate with respect to: s9 and s0
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s9 and s37
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s9 and s47
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s9 and s70
# Result After Differentiation:
# s85*s122
# Degree : 2
#
#
# Differentiate with respect to: s9 and s84
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s9 and s85
# Result After Differentiation:
# s70*s122
# Degree : 2
#
#
# Differentiate with respect to: s9 and s91
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s9 and s107
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s9 and s122
# Result After Differentiation:
# s0 + s37 + s47 + s70*s85 + s84 + s91 + s107 + k0 + k37
# Degree : 2
#
#
# Differentiate with respect to: s15 and s107
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s15 and s122
# Result After Differentiation:
# s107
# Degree : 1
#
#
# Differentiate with respect to: s37 and s9
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s37 and s56
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s37 and s79
# Result After Differentiation:
# s94*s122
# Degree : 2
#
#
# Differentiate with respect to: s37 and s85
# Result After Differentiation:
# s100
# Degree : 1
#
#
# Differentiate with respect to: s37 and s94
# Result After Differentiation:
# s79*s122
# Degree : 2
#
#
# Differentiate with respect to: s37 and s100
# Result After Differentiation:
# s85 + s122
# Degree : 1
#
#
# Differentiate with respect to: s37 and s122
# Result After Differentiation:
# s9 + s56 + s79*s94 + s100 + k9 + 1
# Degree : 2
#
#
# Differentiate with respect to: s47 and s9
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s47 and s56
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s47 and s79
# Result After Differentiation:
# s94*s122
# Degree : 2
#
#
# Differentiate with respect to: s47 and s94
# Result After Differentiation:
# s79*s122
# Degree : 2
#
#
# Differentiate with respect to: s47 and s100
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s47 and s122
# Result After Differentiation:
# s9 + s56 + s79*s94 + s100 + k9 + 1
# Degree : 2
#
#
# Differentiate with respect to: s52 and s70
# Result After Differentiation:
# s85
# Degree : 1
#
#
# Differentiate with respect to: s52 and s85
# Result After Differentiation:
# s70
# Degree : 1
#
#
# Differentiate with respect to: s52 and s107
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s52 and s122
# Result After Differentiation:
# s107
# Degree : 1
#
#
# Differentiate with respect to: s56 and s0
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s56 and s37
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s56 and s47
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s56 and s70
# Result After Differentiation:
# s85*s122
# Degree : 2
#
#
# Differentiate with respect to: s56 and s84
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s56 and s85
# Result After Differentiation:
# s70*s122
# Degree : 2
#
#
# Differentiate with respect to: s56 and s91
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s56 and s107
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s56 and s122
# Result After Differentiation:
# s0 + s37 + s47 + s70*s85 + s84 + s91 + s107 + k0 + k37
# Degree : 2
#
#
# Differentiate with respect to: s62 and s107
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s62 and s122
# Result After Differentiation:
# s107
# Degree : 1
#
#
# Differentiate with respect to: s70 and s9
# Result After Differentiation:
# s85*s122
# Degree : 2
#
#
# Differentiate with respect to: s70 and s52
# Result After Differentiation:
# s85
# Degree : 1
#
#
# Differentiate with respect to: s70 and s56
# Result After Differentiation:
# s85*s122
# Degree : 2
#
#
# Differentiate with respect to: s70 and s99
# Result After Differentiation:
# s85
# Degree : 1
#
#
# Differentiate with respect to: s70 and s100
# Result After Differentiation:
# s85*s122
# Degree : 2
#
#
# Differentiate with respect to: s79 and s0
# Result After Differentiation:
# s94*s122
# Degree : 2
#
#
# Differentiate with respect to: s79 and s37
# Result After Differentiation:
# s94*s122
# Degree : 2
#
#
# Differentiate with respect to: s79 and s47
# Result After Differentiation:
# s94*s122
# Degree : 2
# Differentiate with respect to: s79 and s84
# Result After Differentiation:
# s94*s122
# Degree : 2
#
#
# Differentiate with respect to: s79 and s91
# Result After Differentiation:
# s94*s122
# Degree : 2
#
#
# Differentiate with respect to: s79 and s107
# Result After Differentiation:
# s94*s122
# Degree : 2
#
#
# Differentiate with respect to: s84 and s9
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s84 and s56
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s84 and s79
# Result After Differentiation:
# s94*s122
# Degree : 2
#
#
# Differentiate with respect to: s84 and s85
# Result After Differentiation:
# s100
# Degree : 1
#
#
# Differentiate with respect to: s84 and s94
# Result After Differentiation:
# s79*s122
# Degree : 2
#
#
# Differentiate with respect to: s84 and s100
# Result After Differentiation:
# s85 + s122
# Degree : 1
#
#
# Differentiate with respect to: s84 and s122
# Result After Differentiation:
# s9 + s56 + s79*s94 + s100 + k9 + 1
# Degree : 2
#
#
# Differentiate with respect to: s85 and s9
# Result After Differentiation:
# s70*s122
# Degree : 2
#
#
# Differentiate with respect to: s85 and s37
# Result After Differentiation:
# s100
# Degree : 1
#
#
# Differentiate with respect to: s85 and s52
# Result After Differentiation:
# s70
# Degree : 1
#
#
# Differentiate with respect to: s85 and s56
# Result After Differentiation:
# s70*s122
# Degree : 2
#
#
# Differentiate with respect to: s85 and s84
# Result After Differentiation:
# s100
# Degree : 1
#
#
# Differentiate with respect to: s85 and s99
# Result After Differentiation:
# s70
# Degree : 1
#
#
# Differentiate with respect to: s85 and s100
# Result After Differentiation:
# s37 + s70*s122 + s84 + s107*s122 + k37 + 1
# Degree : 2
#
#
# Differentiate with respect to: s85 and s107
# Result After Differentiation:
# s100*s122
# Degree : 2
#
#
# Differentiate with respect to: s91 and s9
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s91 and s56
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s91 and s79
# Result After Differentiation:
# s94*s122
# Degree : 2
#
#
# Differentiate with respect to: s91 and s94
# Result After Differentiation:
# s79*s122
# Degree : 2
#
#
# Differentiate with respect to: s91 and s100
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s91 and s122
# Result After Differentiation:
# s9 + s56 + s79*s94 + s100 + k9 + 1
# Degree : 2
#
#
# Differentiate with respect to: s94 and s0
# Result After Differentiation:
# s79*s122
# Degree : 2
#
#
# Differentiate with respect to: s94 and s37
# Result After Differentiation:
# s79*s122
# Degree : 2
#
#
# Differentiate with respect to: s94 and s47
# Result After Differentiation:
# s79*s122
# Degree : 2
#
#
# Differentiate with respect to: s94 and s84
# Result After Differentiation:
# s79*s122
# Degree : 2
#
#
# Differentiate with respect to: s94 and s91
# Result After Differentiation:
# s79*s122
# Degree : 2
#
#
# Differentiate with respect to: s94 and s107
# Result After Differentiation:
# s79*s122
# Degree : 2
#
#
# Differentiate with respect to: s99 and s70
# Result After Differentiation:
# s85
# Degree : 1
#
#
# Differentiate with respect to: s99 and s85
# Result After Differentiation:
# s70
# Degree : 1
#
#
# Differentiate with respect to: s99 and s107
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s99 and s122
# Result After Differentiation:
# s107
# Degree : 1
#
#
# Differentiate with respect to: s100 and s0
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s100 and s37
# Result After Differentiation:
# s85 + s122
# Degree : 1
#
#
# Differentiate with respect to: s100 and s47
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s100 and s70
# Result After Differentiation:
# s85*s122
# Degree : 2
#
#
# Differentiate with respect to: s100 and s84
# Result After Differentiation:
# s85 + s122
# Degree : 1
#
#
# Differentiate with respect to: s100 and s85
# Result After Differentiation:
# s37 + s70*s122 + s84 + s107*s122 + k37 + 1
# Degree : 2
#
#
# Differentiate with respect to: s100 and s91
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s100 and s107
# Result After Differentiation:
# s85*s122 + s122
# Degree : 2
#
#
# Differentiate with respect to: s100 and s122
# Result After Differentiation:
# s0 + s37 + s47 + s70*s85 + s84 + s85*s107 + s91 + s107 + k0 + k37
# Degree : 2
#
#
# Differentiate with respect to: s106 and s107
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s106 and s122
# Result After Differentiation:
# s107
# Degree : 1
#
#
# Differentiate with respect to: s107 and s9
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s107 and s15
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s107 and s52
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s107 and s56
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s107 and s62
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s107 and s79
# Result After Differentiation:
# s94*s122
# Degree : 2
#
#
# Differentiate with respect to: s107 and s85
# Result After Differentiation:
# s100*s122
# Degree : 2
#
#
# Differentiate with respect to: s107 and s94
# Result After Differentiation:
# s79*s122
# Degree : 2
#
#
# Differentiate with respect to: s107 and s99
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s107 and s100
# Result After Differentiation:
# s85*s122 + s122
# Degree : 2
#
#
# Differentiate with respect to: s107 and s106
# Result After Differentiation:
# s122
# Degree : 1
#
#
# Differentiate with respect to: s107 and s122
# Result After Differentiation:
# s9 + s15 + s52 + s56 + s62 + s79*s94 + s85*s100 + s99 + s100 + s106 + k9 + k15 + k52 + 1
# Degree : 2
#
#
# Differentiate with respect to: s122 and s0
# Result After Differentiation:
# s9 + s56 + s79*s94 + s100 + k9 + 1
# Degree : 2
#
#
# Differentiate with respect to: s122 and s9
# Result After Differentiation:
# s0 + s37 + s47 + s70*s85 + s84 + s91 + s107 + k0 + k37
# Degree : 2
#
#
# Differentiate with respect to: s122 and s15
# Result After Differentiation:
# s107
# Degree : 1
#
#
# Differentiate with respect to: s122 and s37
# Result After Differentiation:
# s9 + s56 + s79*s94 + s100 + k9 + 1
# Degree : 2
#
#
# Differentiate with respect to: s122 and s47
# Result After Differentiation:
# s9 + s56 + s79*s94 + s100 + k9 + 1
# Degree : 2
#
#
# Differentiate with respect to: s122 and s52
# Result After Differentiation:
# s107
# Degree : 1
#
#
# Differentiate with respect to: s122 and s56
# Result After Differentiation:
# s0 + s37 + s47 + s70*s85 + s84 + s91 + s107 + k0 + k37
# Degree : 2
#
#
# Differentiate with respect to: s122 and s62
# Result After Differentiation:
# s107
# Degree : 1
#
#
# Differentiate with respect to: s122 and s84
# Result After Differentiation:
# s9 + s56 + s79*s94 + s100 + k9 + 1
# Degree : 2
#
#
# Differentiate with respect to: s122 and s91
# Result After Differentiation:
# s9 + s56 + s79*s94 + s100 + k9 + 1
# Degree : 2
#
#
# Differentiate with respect to: s122 and s99
# Result After Differentiation:
# s107
# Degree : 1
#
#
# Differentiate with respect to: s122 and s100
# Result After Differentiation:
# s0 + s37 + s47 + s70*s85 + s84 + s85*s107 + s91 + s107 + k0 + k37
# Degree : 2
#
#
# Differentiate with respect to: s122 and s106
# Result After Differentiation:
# s107
# Degree : 1
#
#
# Differentiate with respect to: s122 and s107
# Result After Differentiation:
# s9 + s15 + s52 + s56 + s62 + s79*s94 + s85*s100 + s99 + s100 + s106 + k9 + k15 + k52 + 1
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
