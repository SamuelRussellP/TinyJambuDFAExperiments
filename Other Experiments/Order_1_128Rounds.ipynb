# %%
from sage.all import *
from sage.crypto.boolean_function import BooleanFunction
from random import randint
import random
import numpy

#R.<k0, k1, k2, k3, k4, k5, k6, k7, k8, k9, k10, k11, k12, k13, k14, k15, k16, k17, k18, k19, k20, k21, k22, k23, k24, k25, k26, k27, k28, k29, k30, k31, k32, k33, k34, k35, k36, k37, k38, k39, k40, k41, k42, k43, k44, k45, k46, k47, k48, k49, k50, k51, k52, k53, k54, k55, k56, k57, k58, k59, k60, k61, k62, k63, k64, k65, k66, k67, k68, k69, k70, k71, k72, k73, k74, k75, k76, k77, k78, k79, k80, k81, k82, k83, k84, k85, k86, k87, k88, k89, k90, k91, k92, k93, k94, k95, k96, k97, k98, k99, k100, k101, k102, k103, k104, k105, k106, k107, k108, k109, k110, k111, k112, k113, k114, k115, k116, k117, k118, k119, k120, k121, k122, k123, k124, k125, k126, k127, v0, v1, v2, v3, v4, v5, v6, v7, v8, v9, v10, v11, v12, v13, v14, v15, v16, v17, v18, v19, v20, v21, v22, v23, v24, v25, v26, v27, v28, v29, v30, v31, v32, v33, v34, v35, v36, v37, v38, v39, v40, v41, v42, v43, v44, v45, v46, v47, v48, v49, v50, v51, v52, v53, v54, v55, v56, v57, v58, v59, v60, v61, v62, v63, v64, v65, v66, v67, v68, v69, v70, v71, v72, v73, v74, v75, v76, v77, v78, v79, v80, v81, v82, v83, v84, v85, v86, v87, v88, v89, v90, v91, v92, v93, v94, v95> = BooleanPolynomialRing()
R = BooleanPolynomialRing(names=('s0', 's1', 's2', 's3', 's4', 's5', 's6', 's7', 
                                 's8', 's9', 's10', 's11', 's12', 's13', 's14', 's15', 
                                 's16', 's17', 's18', 's19', 's20', 's21', 's22', 's23', 
                                 's24', 's25', 's26', 's27', 's28', 's29', 's30', 's31', 
                                 's32', 's33', 's34', 's35', 's36', 's37', 's38', 's39', 
                                 's40', 's41', 's42', 's43', 's44', 's45', 's46', 's47', 
                                 's48', 's49', 's50', 's51', 's52', 's53', 's54', 's55', 
                                 's56', 's57', 's58', 's59', 's60', 's61', 's62', 's63', 
                                 's64', 's65', 's66', 's67', 's68', 's69', 's70', 's71', 
                                 's72', 's73', 's74', 's75', 's76', 's77', 's78', 's79', 
                                 's80', 's81', 's82', 's83', 's84', 's85', 's86', 's87', 
                                 's88', 's89', 's90', 's91', 's92', 's93', 's94', 's95', 
                                 's96', 's97', 's98', 's99', 's100', 's101', 's102', 's103', 
                                 's104', 's105', 's106', 's107', 's108', 's109', 's110', 's111', 
                                 's112', 's113', 's114', 's115', 's116', 's117', 's118', 's119', 
                                 's120', 's121', 's122', 's123', 's124', 's125', 's126', 's127', 
                                 'k0', 'k1', 'k2', 'k3', 'k4', 'k5', 'k6', 'k7', 
                                 'k8', 'k9', 'k10', 'k11', 'k12', 'k13', 'k14', 'k15', 
                                 'k16', 'k17', 'k18', 'k19', 'k20', 'k21', 'k22', 'k23', 
                                 'k24', 'k25', 'k26', 'k27', 'k28', 'k29', 'k30', 'k31', 
                                 'k32', 'k33', 'k34', 'k35', 'k36', 'k37', 'k38', 'k39', 
                                 'k40', 'k41', 'k42', 'k43', 'k44', 'k45', 'k46', 'k47', 
                                 'k48', 'k49', 'k50', 'k51', 'k52', 'k53', 'k54', 'k55', 
                                 'k56', 'k57', 'k58', 'k59', 'k60', 'k61', 'k62', 'k63', 
                                 'k64', 'k65', 'k66', 'k67', 'k68', 'k69', 'k70', 'k71', 
                                 'k72', 'k73', 'k74', 'k75', 'k76', 'k77', 'k78', 'k79', 
                                 'k80', 'k81', 'k82', 'k83', 'k84', 'k85', 'k86', 'k87', 
                                 'k88', 'k89', 'k90', 'k91', 'k92', 'k93', 'k94', 'k95', 
                                 'k96', 'k97', 'k98', 'k99', 'k100', 'k101', 'k102', 'k103', 
                                 'k104', 'k105', 'k106', 'k107', 'k108', 'k109', 'k110', 'k111', 
                                 'k112', 'k113', 'k114', 'k115', 'k116', 'k117', 'k118', 'k119', 
                                 'k120', 'k121', 'k122', 'k123', 'k124', 'k125', 'k126', 'k127'))
R.inject_variables()
S = list(R.gens()[0:128])
S_128 = list(R.gens()[0:128])
K = list(R.gens()[128:256])
C = R.cover_ring()

eqList = ["eq"]

#State Update
for i in range(128):#try to increase 32 bits at a time
    feedback = S[0] + S[47] + S[70]*S[85] + S[91] + 1 + K[i%128]
    for j in range(127):
        S[j] = S[j+1]
    S[127] = feedback

print('\n')
for i in range (64,96,1): 
    print("S =", i)
    #print(S[i])
    print('\n')
    for j in range (0,128):
        X = R(diff(C(S[i]),C(S_128[j])))
        if X !=0 and X != 1 :
            if X.degree() <= 2:
                print ('Differentiate with respect to:', S_128[j])
                print("Result After Differentiation:")
                print (X)
                print("Degree :", X.degree())
                print('\n')  
    print ('--------------------------------------------------------------------------------------------------------------')
# Out:
# Defining s0, s1, s2, s3, s4, s5, s6, s7, s8, s9, s10, s11, s12, s13, s14, s15, s16, s17, s18, s19, s20, s21, s22, s23, s24, s25, s26, s27, s28, s29, s30, s31, s32, s33, s34, s35, s36, s37, s38, s39, s40, s41, s42, s43, s44, s45, s46, s47, s48, s49, s50, s51, s52, s53, s54, s55, s56, s57, s58, s59, s60, s61, s62, s63, s64, s65, s66, s67, s68, s69, s70, s71, s72, s73, s74, s75, s76, s77, s78, s79, s80, s81, s82, s83, s84, s85, s86, s87, s88, s89, s90, s91, s92, s93, s94, s95, s96, s97, s98, s99, s100, s101, s102, s103, s104, s105, s106, s107, s108, s109, s110, s111, s112, s113, s114, s115, s116, s117, s118, s119, s120, s121, s122, s123, s124, s125, s126, s127, k0, k1, k2, k3, k4, k5, k6, k7, k8, k9, k10, k11, k12, k13, k14, k15, k16, k17, k18, k19, k20, k21, k22, k23, k24, k25, k26, k27, k28, k29, k30, k31, k32, k33, k34, k35, k36, k37, k38, k39, k40, k41, k42, k43, k44, k45, k46, k47, k48, k49, k50, k51, k52, k53, k54, k55, k56, k57, k58, k59, k60, k61, k62, k63, k64, k65, k66, k67, k68, k69, k70, k71, k72, k73, k74, k75, k76, k77, k78, k79, k80, k81, k82, k83, k84, k85, k86, k87, k88, k89, k90, k91, k92, k93, k94, k95, k96, k97, k98, k99, k100, k101, k102, k103, k104, k105, k106, k107, k108, k109, k110, k111, k112, k113, k114, k115, k116, k117, k118, k119, k120, k121, k122, k123, k124, k125, k126, k127
#
#
# S = 64
#
#
# Differentiate with respect to: s6
# Result After Differentiation:
# s21 + s68 + s91*s106 + s112 + k21 + 1
# Degree : 2
#
#
# Differentiate with respect to: s21
# Result After Differentiation:
# s6 + s53 + s76*s91 + s97 + k6 + 1
# Degree : 2
#
#
# Differentiate with respect to: s53
# Result After Differentiation:
# s21 + s68 + s91*s106 + s112 + k21 + 1
# Degree : 2
#
#
# Differentiate with respect to: s68
# Result After Differentiation:
# s6 + s53 + s76*s91 + s97 + k6 + 1
# Degree : 2
#
#
# Differentiate with respect to: s76
# Result After Differentiation:
# s21*s91 + s68*s91 + s91*s106 + s91*s112 + s91*k21 + s91
# Degree : 2
#
#
# Differentiate with respect to: s91
# Result After Differentiation:
# s6*s106 + s21*s76 + s53*s106 + s68*s76 + s76*s106 + s76*s112 + s76*k21 + s76 + s97*s106 + s106*k6 + s106
# Degree : 2
#
#
# Differentiate with respect to: s97
# Result After Differentiation:
# s21 + s68 + s91*s106 + k21 + 1
# Degree : 2
#
#
# Differentiate with respect to: s106
# Result After Differentiation:
# s6*s91 + s53*s91 + s76*s91 + s91*s97 + s91*k6 + s91
# Degree : 2
#
#
# Differentiate with respect to: s112
# Result After Differentiation:
# s6 + s53 + s76*s91 + k6 + 1
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 65
#
#
# Differentiate with respect to: s7
# Result After Differentiation:
# s22 + s69 + s92*s107 + s113 + k22 + 1
# Degree : 2
#
#
# Differentiate with respect to: s22
# Result After Differentiation:
# s7 + s54 + s77*s92 + s98 + k7 + 1
# Degree : 2
#
#
# Differentiate with respect to: s54
# Result After Differentiation:
# s22 + s69 + s92*s107 + s113 + k22 + 1
# Degree : 2
#
#
# Differentiate with respect to: s69
# Result After Differentiation:
# s7 + s54 + s77*s92 + s98 + k7 + 1
# Degree : 2
#
#
# Differentiate with respect to: s77
# Result After Differentiation:
# s22*s92 + s69*s92 + s92*s107 + s92*s113 + s92*k22 + s92
# Degree : 2
#
#
# Differentiate with respect to: s92
# Result After Differentiation:
# s7*s107 + s22*s77 + s54*s107 + s69*s77 + s77*s107 + s77*s113 + s77*k22 + s77 + s98*s107 + s107*k7 + s107
# Degree : 2
#
#
# Differentiate with respect to: s98
# Result After Differentiation:
# s22 + s69 + s92*s107 + k22 + 1
# Degree : 2
#
#
# Differentiate with respect to: s107
# Result After Differentiation:
# s7*s92 + s54*s92 + s77*s92 + s92*s98 + s92*k7 + s92
# Degree : 2
#
#
# Differentiate with respect to: s113
# Result After Differentiation:
# s7 + s54 + s77*s92 + k7 + 1
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 66
#
#
# Differentiate with respect to: s8
# Result After Differentiation:
# s23 + s70 + s93*s108 + s114 + k23 + 1
# Degree : 2
#
#
# Differentiate with respect to: s23
# Result After Differentiation:
# s8 + s55 + s78*s93 + s99 + k8 + 1
# Degree : 2
#
#
# Differentiate with respect to: s55
# Result After Differentiation:
# s23 + s70 + s93*s108 + s114 + k23 + 1
# Degree : 2
#
#
# Differentiate with respect to: s70
# Result After Differentiation:
# s8 + s55 + s78*s93 + s99 + k8 + 1
# Degree : 2
#
#
# Differentiate with respect to: s78
# Result After Differentiation:
# s23*s93 + s70*s93 + s93*s108 + s93*s114 + s93*k23 + s93
# Degree : 2
#
#
# Differentiate with respect to: s93
# Result After Differentiation:
# s8*s108 + s23*s78 + s55*s108 + s70*s78 + s78*s108 + s78*s114 + s78*k23 + s78 + s99*s108 + s108*k8 + s108
# Degree : 2
#
#
# Differentiate with respect to: s99
# Result After Differentiation:
# s23 + s70 + s93*s108 + k23 + 1
# Degree : 2
#
#
# Differentiate with respect to: s108
# Result After Differentiation:
# s8*s93 + s55*s93 + s78*s93 + s93*s99 + s93*k8 + s93
# Degree : 2
#
#
# Differentiate with respect to: s114
# Result After Differentiation:
# s8 + s55 + s78*s93 + k8 + 1
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 67
#
#
# Differentiate with respect to: s9
# Result After Differentiation:
# s24 + s71 + s94*s109 + s115 + k24 + 1
# Degree : 2
#
#
# Differentiate with respect to: s24
# Result After Differentiation:
# s9 + s56 + s79*s94 + s100 + k9 + 1
# Degree : 2
#
#
# Differentiate with respect to: s56
# Result After Differentiation:
# s24 + s71 + s94*s109 + s115 + k24 + 1
# Degree : 2
#
#
# Differentiate with respect to: s71
# Result After Differentiation:
# s9 + s56 + s79*s94 + s100 + k9 + 1
# Degree : 2
#
#
# Differentiate with respect to: s79
# Result After Differentiation:
# s24*s94 + s71*s94 + s94*s109 + s94*s115 + s94*k24 + s94
# Degree : 2
#
#
# Differentiate with respect to: s94
# Result After Differentiation:
# s9*s109 + s24*s79 + s56*s109 + s71*s79 + s79*s109 + s79*s115 + s79*k24 + s79 + s100*s109 + s109*k9 + s109
# Degree : 2
#
#
# Differentiate with respect to: s100
# Result After Differentiation:
# s24 + s71 + s94*s109 + k24 + 1
# Degree : 2
#
#
# Differentiate with respect to: s109
# Result After Differentiation:
# s9*s94 + s56*s94 + s79*s94 + s94*s100 + s94*k9 + s94
# Degree : 2
#
#
# Differentiate with respect to: s115
# Result After Differentiation:
# s9 + s56 + s79*s94 + k9 + 1
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 68
#
#
# Differentiate with respect to: s10
# Result After Differentiation:
# s25 + s72 + s95*s110 + s116 + k25 + 1
# Degree : 2
#
#
# Differentiate with respect to: s25
# Result After Differentiation:
# s10 + s57 + s80*s95 + s101 + k10 + 1
# Degree : 2
#
#
# Differentiate with respect to: s57
# Result After Differentiation:
# s25 + s72 + s95*s110 + s116 + k25 + 1
# Degree : 2
#
#
# Differentiate with respect to: s72
# Result After Differentiation:
# s10 + s57 + s80*s95 + s101 + k10 + 1
# Degree : 2
#
#
# Differentiate with respect to: s80
# Result After Differentiation:
# s25*s95 + s72*s95 + s95*s110 + s95*s116 + s95*k25 + s95
# Degree : 2
#
#
# Differentiate with respect to: s95
# Result After Differentiation:
# s10*s110 + s25*s80 + s57*s110 + s72*s80 + s80*s110 + s80*s116 + s80*k25 + s80 + s101*s110 + s110*k10 + s110
# Degree : 2
#
#
# Differentiate with respect to: s101
# Result After Differentiation:
# s25 + s72 + s95*s110 + k25 + 1
# Degree : 2
#
#
# Differentiate with respect to: s110
# Result After Differentiation:
# s10*s95 + s57*s95 + s80*s95 + s95*s101 + s95*k10 + s95
# Degree : 2
#
#
# Differentiate with respect to: s116
# Result After Differentiation:
# s10 + s57 + s80*s95 + k10 + 1
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 69
#
#
# Differentiate with respect to: s11
# Result After Differentiation:
# s26 + s73 + s96*s111 + s117 + k26 + 1
# Degree : 2
#
#
# Differentiate with respect to: s26
# Result After Differentiation:
# s11 + s58 + s81*s96 + s102 + k11 + 1
# Degree : 2
#
#
# Differentiate with respect to: s58
# Result After Differentiation:
# s26 + s73 + s96*s111 + s117 + k26 + 1
# Degree : 2
#
#
# Differentiate with respect to: s73
# Result After Differentiation:
# s11 + s58 + s81*s96 + s102 + k11 + 1
# Degree : 2
#
#
# Differentiate with respect to: s81
# Result After Differentiation:
# s26*s96 + s73*s96 + s96*s111 + s96*s117 + s96*k26 + s96
# Degree : 2
#
#
# Differentiate with respect to: s96
# Result After Differentiation:
# s11*s111 + s26*s81 + s58*s111 + s73*s81 + s81*s111 + s81*s117 + s81*k26 + s81 + s102*s111 + s111*k11 + s111
# Degree : 2
#
#
# Differentiate with respect to: s102
# Result After Differentiation:
# s26 + s73 + s96*s111 + k26 + 1
# Degree : 2
#
#
# Differentiate with respect to: s111
# Result After Differentiation:
# s11*s96 + s58*s96 + s81*s96 + s96*s102 + s96*k11 + s96
# Degree : 2
#
#
# Differentiate with respect to: s117
# Result After Differentiation:
# s11 + s58 + s81*s96 + k11 + 1
# Degree : 2
# --------------------------------------------------------------------------------------------------------------
# S = 70
#
#
# Differentiate with respect to: s12
# Result After Differentiation:
# s27 + s74 + s97*s112 + s118 + k27 + 1
# Degree : 2
#
#
# Differentiate with respect to: s27
# Result After Differentiation:
# s12 + s59 + s82*s97 + s103 + k12 + 1
# Degree : 2
#
#
# Differentiate with respect to: s59
# Result After Differentiation:
# s27 + s74 + s97*s112 + s118 + k27 + 1
# Degree : 2
#
#
# Differentiate with respect to: s74
# Result After Differentiation:
# s12 + s59 + s82*s97 + s103 + k12 + 1
# Degree : 2
#
#
# Differentiate with respect to: s82
# Result After Differentiation:
# s27*s97 + s74*s97 + s97*s112 + s97*s118 + s97*k27 + s97
# Degree : 2
#
#
# Differentiate with respect to: s97
# Result After Differentiation:
# s12*s112 + s27*s82 + s59*s112 + s74*s82 + s82*s112 + s82*s118 + s82*k27 + s82 + s103*s112 + s112*k12 + s112
# Degree : 2
#
#
# Differentiate with respect to: s103
# Result After Differentiation:
# s27 + s74 + s97*s112 + k27 + 1
# Degree : 2
#
#
# Differentiate with respect to: s112
# Result After Differentiation:
# s12*s97 + s59*s97 + s82*s97 + s97*s103 + s97*k12 + s97
# Degree : 2
#
#
# Differentiate with respect to: s118
# Result After Differentiation:
# s12 + s59 + s82*s97 + k12 + 1
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 71
#
#
# Differentiate with respect to: s13
# Result After Differentiation:
# s28 + s75 + s98*s113 + s119 + k28 + 1
# Degree : 2
#
#
# Differentiate with respect to: s28
# Result After Differentiation:
# s13 + s60 + s83*s98 + s104 + k13 + 1
# Degree : 2
#
#
# Differentiate with respect to: s60
# Result After Differentiation:
# s28 + s75 + s98*s113 + s119 + k28 + 1
# Degree : 2
#
#
# Differentiate with respect to: s75
# Result After Differentiation:
# s13 + s60 + s83*s98 + s104 + k13 + 1
# Degree : 2
#
#
# Differentiate with respect to: s83
# Result After Differentiation:
# s28*s98 + s75*s98 + s98*s113 + s98*s119 + s98*k28 + s98
# Degree : 2
#
#
# Differentiate with respect to: s98
# Result After Differentiation:
# s13*s113 + s28*s83 + s60*s113 + s75*s83 + s83*s113 + s83*s119 + s83*k28 + s83 + s104*s113 + s113*k13 + s113
# Degree : 2
#
#
# Differentiate with respect to: s104
# Result After Differentiation:
# s28 + s75 + s98*s113 + k28 + 1
# Degree : 2
#
#
# Differentiate with respect to: s113
# Result After Differentiation:
# s13*s98 + s60*s98 + s83*s98 + s98*s104 + s98*k13 + s98
# Degree : 2
#
#
# Differentiate with respect to: s119
# Result After Differentiation:
# s13 + s60 + s83*s98 + k13 + 1
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 72
#
#
# Differentiate with respect to: s14
# Result After Differentiation:
# s29 + s76 + s99*s114 + s120 + k29 + 1
# Degree : 2
#
#
# Differentiate with respect to: s29
# Result After Differentiation:
# s14 + s61 + s84*s99 + s105 + k14 + 1
# Degree : 2
#
#
# Differentiate with respect to: s61
# Result After Differentiation:
# s29 + s76 + s99*s114 + s120 + k29 + 1
# Degree : 2
#
#
# Differentiate with respect to: s76
# Result After Differentiation:
# s14 + s61 + s84*s99 + s105 + k14 + 1
# Degree : 2
#
#
# Differentiate with respect to: s84
# Result After Differentiation:
# s29*s99 + s76*s99 + s99*s114 + s99*s120 + s99*k29 + s99
# Degree : 2
#
#
# Differentiate with respect to: s99
# Result After Differentiation:
# s14*s114 + s29*s84 + s61*s114 + s76*s84 + s84*s114 + s84*s120 + s84*k29 + s84 + s105*s114 + s114*k14 + s114
# Degree : 2
#
#
# Differentiate with respect to: s105
# Result After Differentiation:
# s29 + s76 + s99*s114 + k29 + 1
# Degree : 2
#
#
# Differentiate with respect to: s114
# Result After Differentiation:
# s14*s99 + s61*s99 + s84*s99 + s99*s105 + s99*k14 + s99
# Degree : 2
#
#
# Differentiate with respect to: s120
# Result After Differentiation:
# s14 + s61 + s84*s99 + k14 + 1
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 73
#
#
# Differentiate with respect to: s15
# Result After Differentiation:
# s30 + s77 + s100*s115 + s121 + k30 + 1
# Degree : 2
#
#
# Differentiate with respect to: s30
# Result After Differentiation:
# s15 + s62 + s85*s100 + s106 + k15 + 1
# Degree : 2
#
#
# Differentiate with respect to: s62
# Result After Differentiation:
# s30 + s77 + s100*s115 + s121 + k30 + 1
# Degree : 2
#
#
# Differentiate with respect to: s77
# Result After Differentiation:
# s15 + s62 + s85*s100 + s106 + k15 + 1
# Degree : 2
#
#
# Differentiate with respect to: s85
# Result After Differentiation:
# s30*s100 + s77*s100 + s100*s115 + s100*s121 + s100*k30 + s100
# Degree : 2
#
#
# Differentiate with respect to: s100
# Result After Differentiation:
# s15*s115 + s30*s85 + s62*s115 + s77*s85 + s85*s115 + s85*s121 + s85*k30 + s85 + s106*s115 + s115*k15 + s115
# Degree : 2
#
#
# Differentiate with respect to: s106
# Result After Differentiation:
# s30 + s77 + s100*s115 + k30 + 1
# Degree : 2
#
#
# Differentiate with respect to: s115
# Result After Differentiation:
# s15*s100 + s62*s100 + s85*s100 + s100*s106 + s100*k15 + s100
# Degree : 2
#
#
# Differentiate with respect to: s121
# Result After Differentiation:
# s15 + s62 + s85*s100 + k15 + 1
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 74
#
#
# Differentiate with respect to: s16
# Result After Differentiation:
# s31 + s78 + s101*s116 + s122 + k31 + 1
# Degree : 2
#
#
# Differentiate with respect to: s31
# Result After Differentiation:
# s16 + s63 + s86*s101 + s107 + k16 + 1
# Degree : 2
#
#
# Differentiate with respect to: s63
# Result After Differentiation:
# s31 + s78 + s101*s116 + s122 + k31 + 1
# Degree : 2
#
#
# Differentiate with respect to: s70
# Result After Differentiation:
# s85
# Degree : 1
#
#
# Differentiate with respect to: s78
# Result After Differentiation:
# s16 + s63 + s86*s101 + s107 + k16 + 1
# Degree : 2
#
#
# Differentiate with respect to: s85
# Result After Differentiation:
# s70
# Degree : 1
#
#
# Differentiate with respect to: s86
# Result After Differentiation:
# s31*s101 + s78*s101 + s101*s116 + s101*s122 + s101*k31 + s101
# Degree : 2
#
#
# Differentiate with respect to: s101
# Result After Differentiation:
# s16*s116 + s31*s86 + s63*s116 + s78*s86 + s86*s116 + s86*s122 + s86*k31 + s86 + s107*s116 + s116*k16 + s116
# Degree : 2
#
#
# Differentiate with respect to: s107
# Result After Differentiation:
# s31 + s78 + s101*s116 + k31 + 1
# Degree : 2
#
#
# Differentiate with respect to: s116
# Result After Differentiation:
# s16*s101 + s63*s101 + s86*s101 + s101*s107 + s101*k16 + s101
# Degree : 2
#
#
# Differentiate with respect to: s122
# Result After Differentiation:
# s16 + s63 + s86*s101 + k16 + 1
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 75
#
#
# Differentiate with respect to: s17
# Result After Differentiation:
# s32 + s79 + s102*s117 + s123 + k32 + 1
# Degree : 2
#
#
# Differentiate with respect to: s32
# Result After Differentiation:
# s17 + s64 + s87*s102 + s108 + k17 + 1
# Degree : 2
#
#
# Differentiate with respect to: s64
# Result After Differentiation:
# s32 + s79 + s102*s117 + s123 + k32 + 1
# Degree : 2
#
#
# Differentiate with respect to: s71
# Result After Differentiation:
# s86
# Degree : 1
#
#
# Differentiate with respect to: s79
# Result After Differentiation:
# s17 + s64 + s87*s102 + s108 + k17 + 1
# Degree : 2
#
#
# Differentiate with respect to: s86
# Result After Differentiation:
# s71
# Degree : 1
#
#
# Differentiate with respect to: s87
# Result After Differentiation:
# s32*s102 + s79*s102 + s102*s117 + s102*s123 + s102*k32 + s102
# Degree : 2
#
#
# Differentiate with respect to: s102
# Result After Differentiation:
# s17*s117 + s32*s87 + s64*s117 + s79*s87 + s87*s117 + s87*s123 + s87*k32 + s87 + s108*s117 + s117*k17 + s117
# Degree : 2
#
#
# Differentiate with respect to: s108
# Result After Differentiation:
# s32 + s79 + s102*s117 + k32 + 1
# Degree : 2
#
#
# Differentiate with respect to: s117
# Result After Differentiation:
# s17*s102 + s64*s102 + s87*s102 + s102*s108 + s102*k17 + s102
# Degree : 2
#
#
# Differentiate with respect to: s123
# Result After Differentiation:
# s17 + s64 + s87*s102 + k17 + 1
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 76
#
#
# Differentiate with respect to: s18
# Result After Differentiation:
# s33 + s80 + s103*s118 + s124 + k33 + 1
# Degree : 2
#
#
# Differentiate with respect to: s33
# Result After Differentiation:
# s18 + s65 + s88*s103 + s109 + k18 + 1
# Degree : 2
#
#
# Differentiate with respect to: s65
# Result After Differentiation:
# s33 + s80 + s103*s118 + s124 + k33 + 1
# Degree : 2
#
#
# Differentiate with respect to: s72
# Result After Differentiation:
# s87
# Degree : 1
#
#
# Differentiate with respect to: s80
# Result After Differentiation:
# s18 + s65 + s88*s103 + s109 + k18 + 1
# Degree : 2
#
#
# Differentiate with respect to: s87
# Result After Differentiation:
# s72
# Degree : 1
#
#
# Differentiate with respect to: s88
# Result After Differentiation:
# s33*s103 + s80*s103 + s103*s118 + s103*s124 + s103*k33 + s103
# Degree : 2
#
#
# Differentiate with respect to: s103
# Result After Differentiation:
# s18*s118 + s33*s88 + s65*s118 + s80*s88 + s88*s118 + s88*s124 + s88*k33 + s88 + s109*s118 + s118*k18 + s118
# Degree : 2
#
#
# Differentiate with respect to: s109
# Result After Differentiation:
# s33 + s80 + s103*s118 + k33 + 1
# Degree : 2
#
#
# Differentiate with respect to: s118
# Result After Differentiation:
# s18*s103 + s65*s103 + s88*s103 + s103*s109 + s103*k18 + s103
# Degree : 2
#
#
# Differentiate with respect to: s124
# Result After Differentiation:
# s18 + s65 + s88*s103 + k18 + 1
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 77
# Differentiate with respect to: s19
# Result After Differentiation:
# s34 + s81 + s104*s119 + s125 + k34 + 1
# Degree : 2
#
#
# Differentiate with respect to: s34
# Result After Differentiation:
# s19 + s66 + s89*s104 + s110 + k19 + 1
# Degree : 2
#
#
# Differentiate with respect to: s66
# Result After Differentiation:
# s34 + s81 + s104*s119 + s125 + k34 + 1
# Degree : 2
#
#
# Differentiate with respect to: s73
# Result After Differentiation:
# s88
# Degree : 1
#
#
# Differentiate with respect to: s81
# Result After Differentiation:
# s19 + s66 + s89*s104 + s110 + k19 + 1
# Degree : 2
#
#
# Differentiate with respect to: s88
# Result After Differentiation:
# s73
# Degree : 1
#
#
# Differentiate with respect to: s89
# Result After Differentiation:
# s34*s104 + s81*s104 + s104*s119 + s104*s125 + s104*k34 + s104
# Degree : 2
#
#
# Differentiate with respect to: s104
# Result After Differentiation:
# s19*s119 + s34*s89 + s66*s119 + s81*s89 + s89*s119 + s89*s125 + s89*k34 + s89 + s110*s119 + s119*k19 + s119
# Degree : 2
#
#
# Differentiate with respect to: s110
# Result After Differentiation:
# s34 + s81 + s104*s119 + k34 + 1
# Degree : 2
#
#
# Differentiate with respect to: s119
# Result After Differentiation:
# s19*s104 + s66*s104 + s89*s104 + s104*s110 + s104*k19 + s104
# Degree : 2
#
#
# Differentiate with respect to: s125
# Result After Differentiation:
# s19 + s66 + s89*s104 + k19 + 1
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 78
#
#
# Differentiate with respect to: s20
# Result After Differentiation:
# s35 + s82 + s105*s120 + s126 + k35 + 1
# Degree : 2
#
#
# Differentiate with respect to: s35
# Result After Differentiation:
# s20 + s67 + s90*s105 + s111 + k20 + 1
# Degree : 2
#
#
# Differentiate with respect to: s67
# Result After Differentiation:
# s35 + s82 + s105*s120 + s126 + k35 + 1
# Degree : 2
#
#
# Differentiate with respect to: s74
# Result After Differentiation:
# s89
# Degree : 1
#
#
# Differentiate with respect to: s82
# Result After Differentiation:
# s20 + s67 + s90*s105 + s111 + k20 + 1
# Degree : 2
#
#
# Differentiate with respect to: s89
# Result After Differentiation:
# s74
# Degree : 1
#
#
# Differentiate with respect to: s90
# Result After Differentiation:
# s35*s105 + s82*s105 + s105*s120 + s105*s126 + s105*k35 + s105
# Degree : 2
#
#
# Differentiate with respect to: s105
# Result After Differentiation:
# s20*s120 + s35*s90 + s67*s120 + s82*s90 + s90*s120 + s90*s126 + s90*k35 + s90 + s111*s120 + s120*k20 + s120
# Degree : 2
#
#
# Differentiate with respect to: s111
# Result After Differentiation:
# s35 + s82 + s105*s120 + k35 + 1
# Degree : 2
#
#
# Differentiate with respect to: s120
# Result After Differentiation:
# s20*s105 + s67*s105 + s90*s105 + s105*s111 + s105*k20 + s105
# Degree : 2
#
#
# Differentiate with respect to: s126
# Result After Differentiation:
# s20 + s67 + s90*s105 + k20 + 1
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 79
#
#
# Differentiate with respect to: s21
# Result After Differentiation:
# s36 + s83 + s106*s121 + s127 + k36 + 1
# Degree : 2
#
#
# Differentiate with respect to: s36
# Result After Differentiation:
# s21 + s68 + s91*s106 + s112 + k21 + 1
# Degree : 2
#
#
# Differentiate with respect to: s68
# Result After Differentiation:
# s36 + s83 + s106*s121 + s127 + k36 + 1
# Degree : 2
#
#
# Differentiate with respect to: s75
# Result After Differentiation:
# s90
# Degree : 1
#
#
# Differentiate with respect to: s83
# Result After Differentiation:
# s21 + s68 + s91*s106 + s112 + k21 + 1
# Degree : 2
#
#
# Differentiate with respect to: s90
# Result After Differentiation:
# s75
# Degree : 1
#
#
# Differentiate with respect to: s91
# Result After Differentiation:
# s36*s106 + s83*s106 + s106*s121 + s106*s127 + s106*k36 + s106
# Degree : 2
#
#
# Differentiate with respect to: s106
# Result After Differentiation:
# s21*s121 + s36*s91 + s68*s121 + s83*s91 + s91*s121 + s91*s127 + s91*k36 + s91 + s112*s121 + s121*k21 + s121
# Degree : 2
#
#
# Differentiate with respect to: s112
# Result After Differentiation:
# s36 + s83 + s106*s121 + k36 + 1
# Degree : 2
#
#
# Differentiate with respect to: s121
# Result After Differentiation:
# s21*s106 + s68*s106 + s91*s106 + s106*s112 + s106*k21 + s106
# Degree : 2
#
#
# Differentiate with respect to: s127
# Result After Differentiation:
# s21 + s68 + s91*s106 + k21 + 1
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 80
#
#
# Differentiate with respect to: s0
# Result After Differentiation:
# s22 + s69 + s92*s107 + k22 + 1
# Degree : 2
#
#
# Differentiate with respect to: s22
# Result After Differentiation:
# s0 + s37 + s47 + s70*s85 + s84 + s91 + s107*s122 + k0 + k37
# Degree : 2
#
#
# Differentiate with respect to: s37
# Result After Differentiation:
# s22 + s69 + s92*s107 + s113 + k22 + 1
# Degree : 2
#
#
# Differentiate with respect to: s47
# Result After Differentiation:
# s22 + s69 + s92*s107 + k22 + 1
# Degree : 2
#
#
# Differentiate with respect to: s69
# Result After Differentiation:
# s0 + s37 + s47 + s70*s85 + s84 + s91 + s107*s122 + k0 + k37
# Degree : 2
#
#
# Differentiate with respect to: s76
# Result After Differentiation:
# s91
# Degree : 1
#
#
# Differentiate with respect to: s84
# Result After Differentiation:
# s22 + s69 + s92*s107 + s113 + k22 + 1
# Degree : 2
#
#
# Differentiate with respect to: s91
# Result After Differentiation:
# s22 + s69 + s76 + s92*s107 + k22 + 1
# Degree : 2
#
#
# Differentiate with respect to: s113
# Result After Differentiation:
# s37 + s84 + s107*s122 + k37 + 1
# Degree : 2
#
#
# Differentiate with respect to: s122
# Result After Differentiation:
# s22*s107 + s69*s107 + s92*s107 + s107*s113 + s107*k22 + s107
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 81
#
#
# Differentiate with respect to: s1
# Result After Differentiation:
# s23 + s70 + s93*s108 + k23 + 1
# Degree : 2
#
#
# Differentiate with respect to: s23
# Result After Differentiation:
# s1 + s38 + s48 + s71*s86 + s85 + s92 + s108*s123 + k1 + k38
# Degree : 2
#
#
# Differentiate with respect to: s38
# Result After Differentiation:
# s23 + s70 + s93*s108 + s114 + k23 + 1
# Degree : 2
#
#
# Differentiate with respect to: s48
# Result After Differentiation:
# s23 + s70 + s93*s108 + k23 + 1
# Degree : 2
#
#
# Differentiate with respect to: s70
# Result After Differentiation:
# s1 + s38 + s48 + s71*s86 + s92 + s108*s123 + k1 + k38
# Degree : 2
#
#
# Differentiate with respect to: s77
# Result After Differentiation:
# s92
# Degree : 1
#
#
# Differentiate with respect to: s85
# Result After Differentiation:
# s23 + s93*s108 + s114 + k23 + 1
# Degree : 2
#
#
# Differentiate with respect to: s92
# Result After Differentiation:
# s23 + s70 + s77 + s93*s108 + k23 + 1
# Degree : 2
#
#
# Differentiate with respect to: s114
# Result After Differentiation:
# s38 + s85 + s108*s123 + k38 + 1
# Degree : 2
#
#
# Differentiate with respect to: s123
# Result After Differentiation:
# s23*s108 + s70*s108 + s93*s108 + s108*s114 + s108*k23 + s108
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 82
#
#
# Differentiate with respect to: s2
# Result After Differentiation:
# s24 + s71 + s94*s109 + k24 + 1
# Degree : 2
#
#
# Differentiate with respect to: s24
# Result After Differentiation:
# s2 + s39 + s49 + s72*s87 + s86 + s93 + s109*s124 + k2 + k39
# Degree : 2
#
#
# Differentiate with respect to: s39
# Result After Differentiation:
# s24 + s71 + s94*s109 + s115 + k24 + 1
# Degree : 2
#
#
# Differentiate with respect to: s49
# Result After Differentiation:
# s24 + s71 + s94*s109 + k24 + 1
# Degree : 2
#
#
# Differentiate with respect to: s71
# Result After Differentiation:
# s2 + s39 + s49 + s72*s87 + s93 + s109*s124 + k2 + k39
# Degree : 2
#
#
# Differentiate with respect to: s78
# Result After Differentiation:
# s93
# Degree : 1
#
#
# Differentiate with respect to: s86
# Result After Differentiation:
# s24 + s94*s109 + s115 + k24 + 1
# Degree : 2
#
#
# Differentiate with respect to: s93
# Result After Differentiation:
# s24 + s71 + s78 + s94*s109 + k24 + 1
# Degree : 2
#
#
# Differentiate with respect to: s115
# Result After Differentiation:
# s39 + s86 + s109*s124 + k39 + 1
# Degree : 2
#
#
# Differentiate with respect to: s124
# Result After Differentiation:
# s24*s109 + s71*s109 + s94*s109 + s109*s115 + s109*k24 + s109
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 83
#
#
# Differentiate with respect to: s3
# Result After Differentiation:
# s25 + s72 + s95*s110 + k25 + 1
# Degree : 2
#
#
# Differentiate with respect to: s25
# Result After Differentiation:
# s3 + s40 + s50 + s73*s88 + s87 + s94 + s110*s125 + k3 + k40
# Degree : 2
#
#
# Differentiate with respect to: s40
# Result After Differentiation:
# s25 + s72 + s95*s110 + s116 + k25 + 1
# Degree : 2
#
#
# Differentiate with respect to: s50
# Result After Differentiation:
# s25 + s72 + s95*s110 + k25 + 1
# Degree : 2
#
#
# Differentiate with respect to: s72
# Result After Differentiation:
# s3 + s40 + s50 + s73*s88 + s94 + s110*s125 + k3 + k40
# Degree : 2
#
#
# Differentiate with respect to: s79
# Result After Differentiation:
# s94
# Degree : 1
#
#
# Differentiate with respect to: s87
# Result After Differentiation:
# s25 + s95*s110 + s116 + k25 + 1
# Degree : 2
#
#
# Differentiate with respect to: s94
# Result After Differentiation:
# s25 + s72 + s79 + s95*s110 + k25 + 1
# Degree : 2
#
#
# Differentiate with respect to: s116
# Result After Differentiation:
# s40 + s87 + s110*s125 + k40 + 1
# Degree : 2
#
#
# Differentiate with respect to: s125
# Result After Differentiation:
# s25*s110 + s72*s110 + s95*s110 + s110*s116 + s110*k25 + s110
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 84
#
#
# Differentiate with respect to: s4
# Result After Differentiation:
# s26 + s73 + s96*s111 + k26 + 1
# Degree : 2
#
#
# Differentiate with respect to: s26
# Result After Differentiation:
# s4 + s41 + s51 + s74*s89 + s88 + s95 + s111*s126 + k4 + k41
# Degree : 2
#
#
# Differentiate with respect to: s41
# Result After Differentiation:
# s26 + s73 + s96*s111 + s117 + k26 + 1
# Degree : 2
#
#
# Differentiate with respect to: s51
# Result After Differentiation:
# s26 + s73 + s96*s111 + k26 + 1
# Degree : 2
#
#
# Differentiate with respect to: s73
# Result After Differentiation:
# s4 + s41 + s51 + s74*s89 + s95 + s111*s126 + k4 + k41
# Degree : 2
#
#
# Differentiate with respect to: s80
# Result After Differentiation:
# s95
# Degree : 1
#
#
# Differentiate with respect to: s88
# Result After Differentiation:
# s26 + s96*s111 + s117 + k26 + 1
# Degree : 2
#
#
# Differentiate with respect to: s95
# Result After Differentiation:
# s26 + s73 + s80 + s96*s111 + k26 + 1
# Degree : 2
#
#
# Differentiate with respect to: s117
# Result After Differentiation:
# s41 + s88 + s111*s126 + k41 + 1
# Degree : 2
#
#
# Differentiate with respect to: s126
# Result After Differentiation:
# s26*s111 + s73*s111 + s96*s111 + s111*s117 + s111*k26 + s111
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 85
#
#
# Differentiate with respect to: s5
# Result After Differentiation:
# s27 + s74 + s97*s112 + k27 + 1
# Degree : 2
#
#
# Differentiate with respect to: s27
# Result After Differentiation:
# s5 + s42 + s52 + s75*s90 + s89 + s96 + s112*s127 + k5 + k42
# Degree : 2
#
#
# Differentiate with respect to: s42
# Result After Differentiation:
# s27 + s74 + s97*s112 + s118 + k27 + 1
# Degree : 2
#
#
# Differentiate with respect to: s52
# Result After Differentiation:
# s27 + s74 + s97*s112 + k27 + 1
# Degree : 2
#
#
# Differentiate with respect to: s74
# Result After Differentiation:
# s5 + s42 + s52 + s75*s90 + s96 + s112*s127 + k5 + k42
# Degree : 2
#
#
# Differentiate with respect to: s81
# Result After Differentiation:
# s96
# Degree : 1
#
#
# Differentiate with respect to: s89
# Result After Differentiation:
# s27 + s97*s112 + s118 + k27 + 1
# Degree : 2
#
#
# Differentiate with respect to: s96
# Result After Differentiation:
# s27 + s74 + s81 + s97*s112 + k27 + 1
# Degree : 2
#
#
# Differentiate with respect to: s118
# Result After Differentiation:
# s42 + s89 + s112*s127 + k42 + 1
# Degree : 2
#
#
# Differentiate with respect to: s127
# Result After Differentiation:
# s27*s112 + s74*s112 + s97*s112 + s112*s118 + s112*k27 + s112
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 86
#
#
# Differentiate with respect to: s0
# Result After Differentiation:
# s28*s113 + s75*s113 + s98*s113 + s113*s119 + s113*k28 + s113
# Degree : 2
#
#
# Differentiate with respect to: s6
# Result After Differentiation:
# s28 + s75 + s98*s113 + k28 + 1
# Degree : 2
#
#
# Differentiate with respect to: s43
# Result After Differentiation:
# s28 + s75 + s98*s113 + s119 + k28 + 1
# Degree : 2
#
#
# Differentiate with respect to: s47
# Result After Differentiation:
# s28*s113 + s75*s113 + s98*s113 + s113*s119 + s113*k28 + s113
# Degree : 2
#
#
# Differentiate with respect to: s53
# Result After Differentiation:
# s28 + s75 + s98*s113 + k28 + 1
# Degree : 2
#
#
# Differentiate with respect to: s82
# Result After Differentiation:
# s97
# Degree : 1
#
#
# Differentiate with respect to: s90
# Result After Differentiation:
# s28 + s98*s113 + s119 + k28 + 1
# Degree : 2
#
#
# Differentiate with respect to: s97
# Result After Differentiation:
# s28 + s75 + s82 + s98*s113 + k28 + 1
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 87
#
#
# Differentiate with respect to: s1
# Result After Differentiation:
# s29*s114 + s76*s114 + s99*s114 + s114*s120 + s114*k29 + s114
# Degree : 2
#
#
# Differentiate with respect to: s7
# Result After Differentiation:
# s29 + s76 + s99*s114 + k29 + 1
# Degree : 2
#
#
# Differentiate with respect to: s44
# Result After Differentiation:
# s29 + s76 + s99*s114 + s120 + k29 + 1
# Degree : 2
#
#
# Differentiate with respect to: s48
# Result After Differentiation:
# s29*s114 + s76*s114 + s99*s114 + s114*s120 + s114*k29 + s114
# Degree : 2
#
#
# Differentiate with respect to: s54
# Result After Differentiation:
# s29 + s76 + s99*s114 + k29 + 1
# Degree : 2
#
#
# Differentiate with respect to: s83
# Result After Differentiation:
# s98
# Degree : 1
#
#
# Differentiate with respect to: s91
# Result After Differentiation:
# s29 + s99*s114 + s120 + k29 + 1
# Degree : 2
#
#
# Differentiate with respect to: s98
# Result After Differentiation:
# s29 + s76 + s83 + s99*s114 + k29 + 1
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 88
#
#
# Differentiate with respect to: s2
# Result After Differentiation:
# s30*s115 + s77*s115 + s100*s115 + s115*s121 + s115*k30 + s115
# Degree : 2
#
#
# Differentiate with respect to: s8
# Result After Differentiation:
# s30 + s77 + s100*s115 + k30 + 1
# Degree : 2
#
#
# Differentiate with respect to: s45
# Result After Differentiation:
# s30 + s77 + s100*s115 + s121 + k30 + 1
# Degree : 2
#
#
# Differentiate with respect to: s49
# Result After Differentiation:
# s30*s115 + s77*s115 + s100*s115 + s115*s121 + s115*k30 + s115
# Degree : 2
#
#
# Differentiate with respect to: s55
# Result After Differentiation:
# s30 + s77 + s100*s115 + k30 + 1
# Degree : 2
#
#
# Differentiate with respect to: s84
# Result After Differentiation:
# s99
# Degree : 1
#
#
# Differentiate with respect to: s92
# Result After Differentiation:
# s30 + s100*s115 + s121 + k30 + 1
# Degree : 2
#
#
# Differentiate with respect to: s99
# Result After Differentiation:
# s30 + s77 + s84 + s100*s115 + k30 + 1
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 89
#
#
# Differentiate with respect to: s3
# Result After Differentiation:
# s31*s116 + s78*s116 + s101*s116 + s116*s122 + s116*k31 + s116
# Degree : 2
#
#
# Differentiate with respect to: s9
# Result After Differentiation:
# s31 + s78 + s101*s116 + k31 + 1
# Degree : 2
#
#
# Differentiate with respect to: s46
# Result After Differentiation:
# s31 + s78 + s101*s116 + s122 + k31 + 1
# Degree : 2
#
#
# Differentiate with respect to: s50
# Result After Differentiation:
# s31*s116 + s78*s116 + s101*s116 + s116*s122 + s116*k31 + s116
# Degree : 2
#
#
# Differentiate with respect to: s56
# Result After Differentiation:
# s31 + s78 + s101*s116 + k31 + 1
# Degree : 2
#
#
# Differentiate with respect to: s85
# Result After Differentiation:
# s100
# Degree : 1
#
#
# Differentiate with respect to: s93
# Result After Differentiation:
# s31 + s101*s116 + s122 + k31 + 1
# Degree : 2
#
#
# Differentiate with respect to: s100
# Result After Differentiation:
# s31 + s78 + s85 + s101*s116 + k31 + 1
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 90
#
#
# Differentiate with respect to: s4
# Result After Differentiation:
# s32*s117 + s79*s117 + s102*s117 + s117*s123 + s117*k32 + s117
# Degree : 2
#
#
# Differentiate with respect to: s10
# Result After Differentiation:
# s32 + s79 + s102*s117 + k32 + 1
# Degree : 2
#
#
# Differentiate with respect to: s47
# Result After Differentiation:
# s32 + s79 + s102*s117 + s123 + k32 + 1
# Degree : 2
#
#
# Differentiate with respect to: s51
# Result After Differentiation:
# s32*s117 + s79*s117 + s102*s117 + s117*s123 + s117*k32 + s117
# Degree : 2
#
#
# Differentiate with respect to: s57
# Result After Differentiation:
# s32 + s79 + s102*s117 + k32 + 1
# Degree : 2
#
#
# Differentiate with respect to: s86
# Result After Differentiation:
# s101
# Degree : 1
#
#
# Differentiate with respect to: s94
# Result After Differentiation:
# s32 + s102*s117 + s123 + k32 + 1
# Degree : 2
#
#
# Differentiate with respect to: s101
# Result After Differentiation:
# s32 + s79 + s86 + s102*s117 + k32 + 1
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 91
#
#
# Differentiate with respect to: s5
# Result After Differentiation:
# s33*s118 + s80*s118 + s103*s118 + s118*s124 + s118*k33 + s118
# Degree : 2
#
#
# Differentiate with respect to: s11
# Result After Differentiation:
# s33 + s80 + s103*s118 + k33 + 1
# Degree : 2
# Differentiate with respect to: s48
# Result After Differentiation:
# s33 + s80 + s103*s118 + s124 + k33 + 1
# Degree : 2
#
#
# Differentiate with respect to: s52
# Result After Differentiation:
# s33*s118 + s80*s118 + s103*s118 + s118*s124 + s118*k33 + s118
# Degree : 2
#
#
# Differentiate with respect to: s58
# Result After Differentiation:
# s33 + s80 + s103*s118 + k33 + 1
# Degree : 2
#
#
# Differentiate with respect to: s87
# Result After Differentiation:
# s102
# Degree : 1
#
#
# Differentiate with respect to: s95
# Result After Differentiation:
# s33 + s103*s118 + s124 + k33 + 1
# Degree : 2
#
#
# Differentiate with respect to: s102
# Result After Differentiation:
# s33 + s80 + s87 + s103*s118 + k33 + 1
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 92
#
#
# Differentiate with respect to: s6
# Result After Differentiation:
# s34*s119 + s81*s119 + s104*s119 + s119*s125 + s119*k34 + s119
# Degree : 2
#
#
# Differentiate with respect to: s12
# Result After Differentiation:
# s34 + s81 + s104*s119 + k34 + 1
# Degree : 2
#
#
# Differentiate with respect to: s49
# Result After Differentiation:
# s34 + s81 + s104*s119 + s125 + k34 + 1
# Degree : 2
#
#
# Differentiate with respect to: s53
# Result After Differentiation:
# s34*s119 + s81*s119 + s104*s119 + s119*s125 + s119*k34 + s119
# Degree : 2
#
#
# Differentiate with respect to: s59
# Result After Differentiation:
# s34 + s81 + s104*s119 + k34 + 1
# Degree : 2
#
#
# Differentiate with respect to: s88
# Result After Differentiation:
# s103
# Degree : 1
#
#
# Differentiate with respect to: s96
# Result After Differentiation:
# s34 + s104*s119 + s125 + k34 + 1
# Degree : 2
#
#
# Differentiate with respect to: s103
# Result After Differentiation:
# s34 + s81 + s88 + s104*s119 + k34 + 1
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 93
#
#
# Differentiate with respect to: s7
# Result After Differentiation:
# s35*s120 + s82*s120 + s105*s120 + s120*s126 + s120*k35 + s120
# Degree : 2
#
#
# Differentiate with respect to: s13
# Result After Differentiation:
# s35 + s82 + s105*s120 + k35 + 1
# Degree : 2
#
#
# Differentiate with respect to: s50
# Result After Differentiation:
# s35 + s82 + s105*s120 + s126 + k35 + 1
# Degree : 2
#
#
# Differentiate with respect to: s54
# Result After Differentiation:
# s35*s120 + s82*s120 + s105*s120 + s120*s126 + s120*k35 + s120
# Degree : 2
#
#
# Differentiate with respect to: s60
# Result After Differentiation:
# s35 + s82 + s105*s120 + k35 + 1
# Degree : 2
#
#
# Differentiate with respect to: s89
# Result After Differentiation:
# s104
# Degree : 1
#
#
# Differentiate with respect to: s97
# Result After Differentiation:
# s35 + s105*s120 + s126 + k35 + 1
# Degree : 2
#
#
# Differentiate with respect to: s104
# Result After Differentiation:
# s35 + s82 + s89 + s105*s120 + k35 + 1
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 94
#
#
# Differentiate with respect to: s8
# Result After Differentiation:
# s36*s121 + s83*s121 + s106*s121 + s121*s127 + s121*k36 + s121
# Degree : 2
#
#
# Differentiate with respect to: s14
# Result After Differentiation:
# s36 + s83 + s106*s121 + k36 + 1
# Degree : 2
#
#
# Differentiate with respect to: s51
# Result After Differentiation:
# s36 + s83 + s106*s121 + s127 + k36 + 1
# Degree : 2
#
#
# Differentiate with respect to: s55
# Result After Differentiation:
# s36*s121 + s83*s121 + s106*s121 + s121*s127 + s121*k36 + s121
# Degree : 2
#
#
# Differentiate with respect to: s61
# Result After Differentiation:
# s36 + s83 + s106*s121 + k36 + 1
# Degree : 2
#
#
# Differentiate with respect to: s90
# Result After Differentiation:
# s105
# Degree : 1
#
#
# Differentiate with respect to: s98
# Result After Differentiation:
# s36 + s106*s121 + s127 + k36 + 1
# Degree : 2
#
#
# Differentiate with respect to: s105
# Result After Differentiation:
# s36 + s83 + s90 + s106*s121 + k36 + 1
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
# S = 95
#
#
# Differentiate with respect to: s15
# Result After Differentiation:
# s37 + s84 + s107*s122 + k37 + 1
# Degree : 2
#
#
# Differentiate with respect to: s52
# Result After Differentiation:
# s0 + s37 + s47 + s70*s85 + s84 + s91 + s107*s122 + k0 + k37
# Degree : 2
#
#
# Differentiate with respect to: s62
# Result After Differentiation:
# s37 + s84 + s107*s122 + k37 + 1
# Degree : 2
#
#
# Differentiate with respect to: s99
# Result After Differentiation:
# s0 + s37 + s47 + s70*s85 + s91 + s107*s122 + k0 + k37
# Degree : 2
#
#
# Differentiate with respect to: s106
# Result After Differentiation:
# s37 + s84 + s91 + s107*s122 + k37 + 1
# Degree : 2
#
#
# --------------------------------------------------------------------------------------------------------------
